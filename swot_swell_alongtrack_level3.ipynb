# %%
import pylab as plt
import numpy as np
import swot_ssh_utils as swot
import swot_swell_utils as swell
from cartopy import crs as ccrs
from netCDF4 import Dataset
import xarray as xr
import sys as sys
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.patches import Rectangle
from datetime import datetime
from netCDF4 import date2num,num2date
from numpy.ma import masked_array

from  lib_filters_obp import *
from wave_physics_functions import wavespec_Efth_to_first3

from matplotlib.pyplot import cm
import pickle
from  lib_filters_obp import *
from scipy import signal
import cmocean
import cmocean.cm as cmo
import glob as glob
lightcmap = cmocean.tools.lighten(cmo.ice, 1)

#PATH_with_functions = '/home/ardhuin/TOOLS/OPTOOLS/PYTHON/'
#sys.path.append(PATH_with_functions)
from  spectral_analysis_functions import *
plt.rcParams.update({'font.size': 18,'savefig.facecolor':'white'})

mpl.rcParams.update({'figure.figsize':[10,6],'axes.grid' : True,'font.size': 14,'savefig.facecolor':'white'})

# %%
modelOK=1;
addglobcur=0;doplot=1
dBE=0
fs1=20

# Defines paths for files and extensions 

modeltag='' #'_T702'
pth_swot='/media/ardhuin/FabLinux/SWOT2/'
pth_WW3_trck='/media/ardhuin/FabLinux/WW3-SWOT/GLOBAL_REF102040/'
pth_results='L3_TEST'+modeltag+'/';

# settings for data flags and swell mask 
cohthr=0.3
flagssha=1E10;
mask_choice=-5;

# settings for figures 
fs1=20;          # font size
dBE=25;dBE2=25;  # shift for colorbar for spectral densities (dB) 
fshrink=0.8;
marginlat=5
makefigs=1;savefile='png'
addarrows=1;
lonshift=0;maplonmin=-180;

# choice of cycle and track and resolution options , with possible restricted latitude range 
#cycle='005';tracks='328';latmax=100;latmin=-100;
cycle='002';tracks='485';lonshift=0;mask_choice=-5;latmin=-25;latmax=-10;
number_res=3; spectra_res='alpha'; vtag='alpha3';
number_res=2; spectra_res='alpha'; vtag='alpha2';
number_res=1; spectra_res='alpha'; vtag='alpha1';
number_res=2; spectra_res='beta'; vtag='beta2';



ntrack=int(tracks)
if (np.mod(ntrack,2)==1):
    td='ascending'
else: 
    td='descending'

# Searches for L3 file ... 
file_list = glob.glob(pth_swot+'SWOT_L3_LR_SSH_*Unsmoothed_'+cycle+'_'+tracks+'*.nc')
file_swot=file_list[0]
tags=file_swot.split(sep='/')
filenopath=tags[-1]
days=filenopath[34:len(filenopath)]
print('Reading file:',file_swot,'##',days)
ddla = xr.open_dataset(file_swot)
#print(ddla)

# This opens the WAVEWATCH III spectra file (computed for B. Molero).
filetr=pth_WW3_trck+'SWOT_WW3-GLOB-30M_'+days[0:6]+'_trck.nc'
print('file for model:',filetr) 
ds_ww3t = xr.open_dataset(filetr)
modang=np.mod(90-ds_ww3t.direction,360)
moddf=ds_ww3t.frequency2.values-ds_ww3t.frequency1.values
modf=ds_ww3t.frequency.values
modnth=np.shape(modang)[0]
moddth=(2*np.pi/modnth)

# Get globcurrent 
if addglobcur==1:
    # defines bounding box
    xt=ddla.longitude[:,20].values
    yt=ddla.latitude[:,20].values
    ind=np.where((yt > latmin-marginlat) & (yt < latmax+5))[0]
    xt=xt[ind[0]:ind[-1]:10];yt=yt[ind[0]:ind[-1]:10]
 
    ds = xr.open_dataset('../dataset-uv-nrt-hourly_20230609T0000Z_P20230726T0000.nc')
    area=[np.floor( np.nanmin([xt]) )-cmapmin,np.floor(latmin)-marginlat,  np.ceil(np.nanmax([xt]) )+cmapmax,   np.ceil(latmax)+5]
    print('YT:',area) 
    print('globlon:',ds.longitude[0].values,ds.longitude[-1].values)
    print('area:', area)

    selection = (
    (ds.longitude+360*lonshift > area[0]) &
    (ds.longitude+360*lonshift < area[2]) &
    (ds.latitude > area[1]) &
    (ds.latitude < area[3]))

    ds_glob = ds.where(selection, drop=True)
    globlon=ds_glob.longitude+360*lonshift
    globlat=ds_glob.latitude
    U=ds_glob.uo[17,0,:,:].squeeze()
    V=ds_glob.vo[17,0,:,:].squeeze()

#fig,axs=plt.subplots(1,2,figsize=(18,10))#,sharey=True,sharex=True)
#fig.savefig('blank.png',dpi=100)

l1=latmin;l2=latmax
if td == 'descending':
   l1=latmax;l2=latmin

# initialise some resolution and other geometry information 
#dx,dy,indxc,ISHIFT,nkxr,nkyr,restab,nX2tab,nY2tab,mtab,ntab,indl,dind,samemask,hemiNS,hemiWE=swell.spec_settings_for_L3(3,'alpha'); vtag='alpha3';
#dx,dy,indxc,ISHIFT,nkxr,nkyr,restab,nX2tab,nY2tab,mtab,ntab,indl,dind,samemask,hemiNS,hemiWE=swell.spec_settings_for_L3(2,'alpha'); vtag='alpha2';
dx,dy,indxc,ISHIFT,nkxr,nkyr,restab,nX2tab,nY2tab,mtab,ntab,indl,dind,samemask,hemiNS,hemiWE=swell.spec_settings_for_L3(number_res,spectra_res);
#dx,dy,indxc,ISHIFT,nkxr,nkyr,restab,nX2tab,nY2tab,mtab,ntab,indl,dind,samemask,hemiNS,hemiWE=swell.spec_settings_for_L3(2,'beta'); vtag='beta2';


ncout='SWOT_L3_LR_Spectra_'+filenopath[26:65]+'_v_'+vtag+'.nc'  #len(filenopath)]
SL3_nc=swell.SWOT_create_L3_spectra(ncout,filenopath,modelOK,restab,nX2tab*2//mtab,nY2tab*2//ntab,modf=modf,moddf=moddf,modang=modang)

step=-1;HsvalueOK=0;


if (np.abs(l1) < 90): 
    ddl,indsub0,indsub1=swot.subset(ddla,[-0.5+float(l1), 0.5+float(l1)])
    ind00=indsub0
else:
    ind00=0
if (np.abs(l2) < 90): 
    ddl,indsub0,indsub1=swot.subset(ddla,[-0.5+float(l2), 0.5+float(l2)])
    ind99=indsub1
else:
    nlines=ddla.dims['num_lines']
    print('DIMS:',nlines)
    ind99=nlines-indl

shifty=ind00

# Start of main loop over along track positions ... 
for indsub0 in np.arange(ind00,ind99,dind):
   step=step+1
   subset_vars = {}
   for varname, var in ddla.data_vars.items():
      if var.dims==2:
        subset_vars[varname] = var[indsub0:indsub0+indl,:]
      else:
         subset_vars[varname] = var[indsub0:indsub0+indl]
      # Combine the subset variables into a new dataset
      ddl = xr.Dataset(subset_vars, attrs=ddla.attrs)

# gets data from SWOT L3 SSH file 
   ssha = ddl.ssha_unedited
   flag = ddl.quality_flag  # L2 : .ssh_karin_2_qual
   ssha = np.where(flag < flagssha, ssha, np.nan)
   sig0 = ddl.sigma0 #sig0_karin_2
   flas = ddl.quality_flag # sig0_karin_2_qual
   lon = ddl.longitude.values
   lat = ddl.latitude.values
   [nline,npix]=np.shape(ssha)

   # there may be a better way to get this ... but here is an angle estimates from the position of near nadir pixeks 
   dlon=lon[nline-10,indxc+ISHIFT]-lon[10,indxc+ISHIFT]
   dlat=lat[nline-10,indxc+ISHIFT]-lat[10,indxc+ISHIFT]
   midlat=0.5*(lat[nline-10,indxc+ISHIFT]+lat[10,indxc+ISHIFT])
   trackangle=-90-np.arctan2(dlat,dlon*np.cos(midlat*np.pi/180))*180/np.pi


   X=(np.arange(npix)-indxc)*dx/1000
   Y=(np.arange(nline)+indsub0-shifty)*dy/1000 # warning the along-track resolutionis not exactly 250 m, more like 235 m 

   for indside in range(2):    # separate the loops over left and right parts
     modelfound=0
     for indres in range(len(restab)):   # loop over different spatial resoltions 
      ires=restab[indres]
      sres=f'{ires:02d}'
      nX2=nX2tab[indres]  # half size of box for which spectrum is computed 
      nY2=nY2tab[indres]
      m=mtab[indres];n=ntab[indres]
      cfac=np.sqrt(n*m)
      # Defines number of spectral boxes for current resolution 
      nindx=nX2tab[0]//nX2tab[indres]+(nX2tab[0]//nX2tab[indres]-1)  # Welch-type 50 % overlap in x direction ... 
      nindy=nY2tab[0]//nY2tab[indres]
      #print('indres:',indres,nindx,nindy)
      if ires==40:
          # array of indices for left edge of each analysis window
         i1array=np.array([indxc-ISHIFT-nX2*2,ISHIFT+indxc])
      if ires==20:
         # Defines area for spectral analysis 
         i1array=np.array([indxc-ISHIFT-nX2*4,indxc-ISHIFT-nX2*3,indxc-ISHIFT-nX2*2, \
                           ISHIFT+indxc,ISHIFT+indxc+nX2,ISHIFT+indxc+nX2*2])
      if ires==10:
         # Defines area for spectral analysis 
         i1array=np.array([indxc-ISHIFT-nX2*8,indxc-ISHIFT-nX2*7,indxc-ISHIFT-nX2*6, \
                           indxc-ISHIFT-nX2*5,indxc-ISHIFT-nX2*4,indxc-ISHIFT-nX2*3, \
                           indxc-ISHIFT-nX2*2, \
                           ISHIFT+indxc,ISHIFT+indxc+nX2,ISHIFT+indxc+nX2*2, \
                           ISHIFT+indxc+nX2*3,ISHIFT+indxc+nX2*4,ISHIFT+indxc+nX2*5, \
                           ISHIFT+indxc+nX2*6])
      
      nxtile=nX2*2//m  # cross-track
      nytile=nY2*2//n  # along-track

# Loops across track and along-track (within given side) 
      for iidx in range(nindx):    
       indx=iidx+indside*nindx
       i1=i1array[indx]
       i2=i1+nX2*2
       for indy in range(nindy):
# cross-track indices
#alongtrack indices
          # needs extra loop here ... 
         j1=nline//2-nY2*(nindy-indy) #10   # centers box on target latitude
         j2=j1+nY2*2
         latc=ddl.latitude[j1+nY2,i1+nX2].values    # WILL HAVE TO CHANGE THIS ... 
         latcr=np.round(latc*2)/2; latcs=f'{abs(latc):3.2f}'+hemiNS[int(np.sign(latc))]
         lonc=lon[j1+nY2,i1+nX2]; 
         loncr=np.round(lonc*2)/2; loncs=f'{abs(lonc):3.2f}'+hemiWE[int(np.sign(lonc))]
         lat_bounds=[-0.5+float(latc), 0.5+float(latc)];
         lonlat=latcs+loncs
         steps=f'{step:05d}'  
         sside='left'
         if indside ==1:
             sside='right'
         #print('selecting area for spectrum:',indx,indy,i1,j1,nY2,nX2, 'latc,lonc:',lonlat) 
         filetag='SWOT_'+cycle+'_'+tracks+'_'+sside+'_'+steps+'_'+lonlat  
         
       
         Xmem=X;
         Ymem=Y;
# NB: with L3 data we do not need the cross-track flip, thus side is forced to "right"
         mybox,mybos,flbox,X,Y,sflip,signMTF,Look=swell.SWOTarray_flip_north_up(dlat,'right',ssha[j1:j2,i1:i2],flas[j1:j2,i1:i2],sig0[j1:j2,i1:i2],Xmem,Ymem)

         if (indres==0 & indside==0):  
            timec=ddl.time.values[j1+nY2]
            print('track vector:',indsub0+j1,dlat,dlon*np.cos(midlat*np.pi/180),trackangle,trackangle+180,'##',dlat,Look,indsub0)
           
         nanarr = np.where(np.isnan(mybox), 1.0,0)  # Need to count these in for  flags ... 
         infarr = np.where(np.isinf(mybox), 1.0,0)  # Need to count these in for  flags ... 
         flaarr = np.where(flbox > 1, 1.0,0)  # Need to count these in for  flags ... 
         fracbad=np.sum((nanarr+infarr).flatten())/((j2-j1)*(i2-i1))
         fracfla=np.sum(flaarr.flatten())/((j2-j1)*(i2-i1))
           
         #print('BAD:',fracbad,fracfla)  
# Computes spectrum from SWOT SSH data
# Note: this uses tiles: we may use these higher resolution estimates to avoid duplication 
         (Eta,Etb,ang,angstd,coh,crosr,phases,ky2,kx2,dky,dkx,detrenda,detrendb,nspec)=FFT2D_two_arrays_nm_detrend_flag(mybox,10**(0.1*mybos),flbox,dy,dx,n,m,detrend='quadratic') #,ffill='none')

         
         if (iidx==0 & indy==0 & ((1-samemask)*step)==0):   
            kxmax=-2*kx2[0,0]
            kymax=-2*ky2[0,0]
            nkxr=nxtile      # twice the SWOT range to allow aliasing computation 
            nkyr=nytile
            dkxr=kxmax/nkxr
            dkyr=kymax/(nkyr-1)  # only true in nkyr is odd ?? 

            kxr=np.linspace(-nkxr*dkxr,(nkxr-1)*dkxr,nkxr*2)
            kyr=np.linspace(-nkyr*dkyr,(nkyr-1)*dkyr,nkyr*2)
            fx_wreg=kxr*1000
            fy_wreg=kyr*1000
            kxr2, kyr2 = np.meshgrid(kxr,kyr,indexing='ij') 
            kn=np.sqrt(kx2**2+ky2**2)*1000
 
            ik1=(nxtile+1)//2;ik2=ik1+nxtile
            jk1=(nytile+1)//2;jk2=jk1+nytile
   
# Defines the spectral response H assocaited to SWOT on board processing and PTR 
            x_xt, w_xt, f_xt, H_xt = get_obp_filter(L_filt = 0.980, f_axis = fx_wreg, plot_flag = False, kernel="parzen")
            x_at, w_at, f_at, H_at = get_obp_filter(L_filt = 1, f_axis = fy_wreg, plot_flag = False, kernel="bharris")
            x_at, w_at, f_obp, H_ptr = get_obp_filter(L_filt = 3, sampling_in = 0.0125,f_axis = fy_wreg, plot_flag = False, kernel="alejandro_azptr")
    
            H = np.repeat(np.array([H_xt]), len(H_at), axis=0).T * np.repeat(np.array([H_at]), len(H_xt), axis=0)
            Hptr = np.repeat(np.array([H_ptr]), len(H_xt), axis=0)
            H2=H*Hptr                     # note that when model data is also used, H3 is defined below to include az cut-off 
            H3=H2

# these filters now have smae dimension as the spectra 
            HH =H[ik1:ik2,jk1:jk2].T
            HH1=Hptr[ik1:ik2,jk1:jk2].T
            HH2=H2[ik1:ik2,jk1:jk2].T
            HH3=H3[ik1:ik2,jk1:jk2].T

         
         if (modelOK > 0 ):
           if (indres == 0):
# Looks for matching wavemodel spectrum 
              modspec,indww3,modelfound,timeww3,lonww3,latww3,distww3,U10,Udir=swell.SWOTfind_model_spectrum(ds_ww3t,lonc,latc,timec)
# Computes kx,ky spectrum from WW3 on fine grid: using even number of k's makes the spectrum non-symmetric 
# warning: this is repeated if indres > 0 because spectral resolution may differ 
           if (modelfound>0 & iidx==0 & indy==0):
               efth=modspec.values;
               [Ef,th1m,sth1m,Hs,Tm0m1,Tm02,Qf,Qkk] = wavespec_Efth_to_first3(efth,modf,moddf, modang.values,moddth) 
               sigu=(Hs/4)*2*np.pi/Tm02
               lambdac=1/((7310/875.0e3)/sigu/(2*np.pi))   # az cut-off wavenumber in cpm
               Hazc = np.exp(-(kyr2*lambdac)**2)        # this is the effect of velocity bunching for sigma0 ... what about the phase? 
               H3=H*Hptr*Hazc
               HH3=H3[ik1:ik2,jk1:jk2].T

# converts the model spectrum to the SWOT (kx,ky) geometry
               Eta_WW3_obp_H2,Eta_WW3_obp_H,Eta_WW3_noa_H2,Eta_WW3_res,Eta_WW3_c,Ekxky,kxm,kym,ix1,iy1= \
                              swell.wavespec_Efth_to_kxky_SWOT(efth,modf,moddf, modang,moddth,f_xt,f_at,H,Hazc,H3, \
                                            kxmax,kymax,dkx,dky,dkxr,dkyr,nxtile,nytile,doublesided=0,verbose=0,trackangle=(trackangle+sflip*180)*np.pi/180)
        


# Defines swell mask  : uses function SWOTdefine_swell_mask
         if (iidx==0 & indy==0 & (samemask*indres)==0):
            mask_adapt=mask_choice
            qual_mask=0
            if (modelfound==0):
               mask_adapt=0
               qual_mask=1
            spec_for_mask=Eta  #/HH3  # if model is not found: uses SWOT for mask ... 
            if mask_adapt == -3 :
               spec_for_mask=Eta_WW3_noa_H2/HH2
            if mask_adapt == -4 :
               spec_for_mask=Eta_WW3_noa_H2
            if mask_adapt == -5 :
               spec_for_mask=Eta_WW3_res
            amask,bmask=swell.SWOTdefine_swell_mask_simple(spec_for_mask,coh,ang,np.nanmedian(mybos),dlat,kx2,ky2,cohthr,cfac,mask_adapt)

            vertices=swell.SWOTspec_mask_polygon(amask) 
                
# Computes model parameters ... 
         if (modelfound > 0):
           if( indres == 0): 
            Eta_WW3_obp_H2_mask=np.where( bmask > 0.5, Eta_WW3_obp_H2,0) 
            var2=np.sum(Eta_WW3_obp_H2.flatten())*dkxr*dkyr; 
            var3=np.sum(Eta_WW3_c.flatten())*dkxr*dkyr;
            Hs_WW3_all=4*np.sqrt(var2)
            Hs_WW3_cut=4*np.sqrt(var3)
            # NB: I was using bmask for this computation before Sept. 2024
            Hs_WW3_mask,Lm_WW3,Lmnew,dm_WW3,Q18_WW3=swell.SWOTspec_to_HsLm(Eta_WW3_obp_H2,kx2,ky2,amask,HH3,trackangle)
            #print('HS WW3 shape:',np.shape(SL3_nc.variables['H18_model']),'##',Hs_WW3_mask,step,indy,indx,indres)
            SL3_nc.variables['efth_model'][step,indy,indx,:,:]=efth
            if step==0:
                SL3_nc.variables['frequency'][:]=modf
                SL3_nc.variables['df'][:]=moddf
                SL3_nc.variables['direction'][:]=modang
            SL3_nc.variables['longitude_model'][step,indy,indx]=lonww3
            SL3_nc.variables['latitude_model'][step,indy,indx]=latww3
            SL3_nc.variables['time_model'][step,indy,indx]=timeww3
            SL3_nc.variables['index_model'][step,indy,indx]=indww3
            SL3_nc.variables['H18_model'][step,indy,indx]=Hs_WW3_mask
            SL3_nc.variables['L18_model'][step,indy,indx]=Lm_WW3
            SL3_nc.variables['d18_model'][step,indy,indx]=dm_WW3
            SL3_nc.variables['Q18_model'][step,indy,indx]=Q18_WW3
            SL3_nc.variables['Hs_model'][step,indy,indx]=Hs
            SL3_nc.variables['Tm02_model'][step,indy,indx]=Tm02
            SL3_nc.variables['lambdac_model'][step,indy,indx]=lambdac
            
####################################################################################
            if ((step < doplot) & (indres==0)):
               fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(6,3.5))
               spec = mpl.gridspec.GridSpec(ncols=2, nrows=1,width_ratios=[6, 5])
               plt.subplots_adjust(left=0.05,bottom=0.1, top=0.92,wspace=0.1,right=0.99)
    
# Plotting WW3 spectrum, same resolution as SWOT spectrum 
               im=ax[0].pcolormesh(kx2*1000,ky2*1000,10*np.log10(Eta_WW3_obp_H2),cmap='viridis',rasterized=True,vmin = -10+dBE, vmax=30+dBE)
               _=ax[0].set_title('model spectrum  (dB)')
               swell.draw_mask(ax[0],kx2,dkx,ky2,dky,vertices,color='w',lw=3) 
                
# Plotting WW3 spectrum, same resolution as SWOT spectrum but 2 x spectral range and no ambiguity in direction 
               im=ax[1].pcolormesh(-kxm[ix1:ix1+nxtile*6]*1000,-kym[iy1:iy1+nxtile*6]*1000,10*np.log10(Ekxky[ix1:ix1+nxtile*6,iy1:iy1+nxtile*6]).T,cmap='viridis',rasterized=True,vmin=-10+dBE2, vmax=30+dBE2)
               _=ax[1].set_title('model unfiltered')
               plt.setp(ax[1].get_yticklabels(), visible=False)
               plt.show()
               fig.savefig(pth_results+filetag+'WW3.png',dpi=100)    

########################### Plots SWOT spectrum E_S(kx,ky)
         if (step < doplot):
            fig,axs= swell.plot_spec(kx2,dkx,ky2,dky,Eta,dBE,vertices)
            if addglobcur==1:
               swell.plot_cur(axs,td,xt,yt,latc,globlon,globlat,U,V,lightcmap)
               axs[1].set_xlim([area[0],area[2]])
               axs[1].set_ylim([area[1],area[3]])

            fig.savefig(pth_results+filetag+'spec.png',dpi=100) 
###############
            fig,axs=swell.plot_coh(kx2,dkx,ky2,dky,coh,np.degrees(ang),vertices)
            fig.savefig(pth_results+filetag+'coh.png',dpi=100)    
        
#########  Stats and integrated parameters
         Eta_SWOT_mask=np.where( amask > 0.5, Eta,0)    
    
         varm=np.sum(Eta.flatten())*dkx*dky;
         var0=np.sum(Eta_SWOT_mask.flatten())*dkx*dky*2;
         Hs_SWOT_all=4*np.sqrt(varm)
         Hs_SWOT=4*np.sqrt(var0)
         Hs_SWOT_mask,Lm_SWOT,Lmnew,dm_SWOT,Q18_SWOT=swell.SWOTspec_to_HsLm(Eta,kx2,ky2,amask,HH2,trackangle)
         HsvalueOK=1

         Xbox=X[i1:i2];Ybox=Y[j1:j2]
        
         boxindices=[indsub0+j1,indsub0+j2,i1,i2]
         sig0mean=np.nanmedian(mybos)
         sig0std=np.nanstd(mybos)

# Write variables to NetCDF file
         if (step==0 & indx==0 & indy==0):
            print('sres:',sres) 
            knc=SL3_nc.variables['kx2_'+sres]
            knc[:,:] = kx2 
            knc=SL3_nc.variables['ky2_'+sres]
            knc[:,:] = ky2 
         
         if (indres==0):
# Old code for npz output ... 
#             if (modelfound > 0):
#               swell.SWOT_save_spectra(pth_results,filenopath,modelfound,cycle,tracks,side,boxindices,\
#                       lonc,latc,timec,trackangle,kx2,ky2,Eta,Etb,coh,ang,crosr,amask,sig0mean,sig0std,HH,HH2,Hs_SWOT_all,Hs_SWOT,Hs_SWOT_mask,Lm_SWOT,dm_SWOT, \
#                       timeww3=timeww3,lonww3=lonww3,latww3=latww3,indww3=indww3,distww3=distww3, \
#                       E_WW3_obp_H=Eta_WW3_obp_H,E_WW3_obp_H2=Eta_WW3_obp_H2,E_WW3_noa_H2=Eta_WW3_noa_H2,Hs_WW3_all=Hs_WW3_all,Hs_WW3_cut=Hs_WW3_cut,\
#                       Hs_WW3_mask=Hs_WW3_mask,Hs=Hs,Tm0m1=Tm0m1,Tm02=Tm02,U10=U10,Udir=Udir,Qkk=Qkk,Lm_WW3=Lm_WW3,dm_WW3=dm_WW3, verbose=0)
#            else:
#               swell.SWOT_save_spectra(pth_results,filenopath,modelfound,cycle,tracks,side,boxindices,\
#                       lonc,latc,timec,trackangle,kx2,ky2,Eta,Etb,coh,ang,crosr,amask,sig0mean,sig0std,HH,HH2,Hs_SWOT_all,Hs_SWOT,Hs_SWOT_mask,Lm_SWOT,dm_SWOT)
            if (indside==0): 
               SL3_time=SL3_nc.variables['time']
               print('time units:',SL3_time.units) # numeric values
               print('timec:',timec) # numeric values
               epoch=np.datetime64('2000-01-01T00:00:00')
               timedt=(timec-epoch)/np.timedelta64(1,'s')
               #timedt=timec.astype(datetime)
               #times = timedt #date2num(timedt, SL3_time.units)
               # Do we really need the time ?  
               SL3_time[step]=timedt
               SL3_nc.variables['trackangle'][step]=trackangle      
            SL3_nc.variables['boxindices_'+sres][step,indy,indx,:]=boxindices
            SL3_nc.variables['coh_SWOT_'+sres][step,indy,indx,:,:]=coh
            SL3_nc.variables['ang_SWOT_'+sres][step,indy,indx,:,:]=np.degrees(ang)
            SL3_nc.variables['crosr_SWOT_'+sres][step,indy,indx,:,:]=crosr
            SL3_nc.variables['Q18_'+sres][step,indy,indx]=Q18_SWOT
         
         SL3_nc.variables['longitude_'+sres][step,indy,indx] = lonc 
         SL3_nc.variables['latitude_'+sres][step,indy,indx] = latc
         SL3_nc.variables['sigma0_mean_'+sres][step,indy,indx]=sig0mean      
         SL3_nc.variables['sigma0_std_'+sres][step,indy,indx]=sig0std      
         SL3_nc.variables['quality_frac_'+sres][step,indy,indx]=fracfla
         SL3_nc.variables['quality_flag_mask_'+sres][step,indy,indx]=qual_mask
         SL3_nc.variables['H18_'+sres][step,indy,indx]=Hs_SWOT_mask
         SL3_nc.variables['L18_'+sres][step,indy,indx]=Lm_SWOT
         SL3_nc.variables['d18_'+sres][step,indy,indx]=dm_SWOT
         SL3_nc.variables['mask_'+sres][step,0,indside,:,:] = amask
         SL3_nc.variables['filter_OBP_'+sres][:,:] = HH
         SL3_nc.variables['filter_PTR_'+sres][:,:] = HH1
        
         Enc=SL3_nc.variables['E_SWOT_'+sres]
         Enc[step,indy,indx,:,:] = Eta 
            
         print('Writing to file for latitude ',latc,' in range [',latmin,latmax,'] , indices:',step,indside,ires,'##',indy,iidx,', size:',np.shape(Enc))
            


        
# This processing is just for display purposes: larger piece of SWOT data used in animations 
     if ( (step < doplot) & (indside == 0)):
            if indside==0:
               I1=indxc-ISHIFT-200;I2=I1+200;J1=0;J2=420;
            if indside==1:
               I1=indxc+ISHIFT;I2=I1+200;J1=0;J2=420;

            SSHA,SIG0,FLAS,X,Y,sflip,signMTF,Look=swell.SWOTarray_flip_north_up(dlat,'right',ssha[J1:J2,I1:I2],flas[J1:J2,I1:I2],sig0[J1:J2,I1:I2],Xmem,Ymem)

            (Eta,Etb,ang,angstd,coh,crosr,phases,ky2,kx2,dky,dkx,detrenda,detrendb,nspec)=FFT2D_two_arrays_nm_detrend_flag(SSHA,10**(0.1*SIG0),FLAS,dy,dx,10,5,detrend='quadratic') #,ffill='none')
            sig0max=np.nanmax(sig0)
            sig0min=np.nanmin(sig0)
            sig0mean=np.nanmedian(sig0)
            sig0std=np.nanstd(sig0)
            YP=Y #-Y[J1]
            fig,axs=plt.subplots(1,2,figsize=(12,10))#,sharey=True,sharex=True)
            plt.subplots_adjust(left=0.1,bottom=0.07, top=0.96,wspace=0.05,right=0.99)
 
            if Look==-1:
               axs=np.roll(axs,1)
               plt.setp(axs[0].get_yticklabels(), visible=False)
               _=axs[1].set_ylabel('along-track (km)',fontsize=fs1)
            else:
               plt.setp(axs[1].get_yticklabels(), visible=False)
               _=axs[0].set_ylabel('along-track (km)',fontsize=fs1)
  
            im=axs[0].pcolormesh(X[I1:I2],YP[J1:J2],detrenda,rasterized=True, cmap=lightcmap,vmin=-0.1,vmax=0.1)
  
            arx0=X[(i1+i2)//2]-7.5*(1-indside);ary0=YP[40];arxd=5;aryd=5;arwid=1;gr=[0.,1,0.]
            if addarrows==1:
               axs[0].arrow(arx0, ary0, arxd*np.sign(dlat)*np.sin(trackangle*np.pi/180), -np.sign(dlat)*aryd*np.cos(trackangle*np.pi/180), linewidth=4,color='k',head_width=arwid) 
               axs[0].text(arx0+arxd*1.4*np.sign(dlat)*np.sin(trackangle*np.pi/180),ary0-np.sign(dlat)*aryd*1.4*np.cos(trackangle*np.pi/180),'N',fontsize=fs1)
               axs[0].arrow(arx0, ary0, 0., 5*np.sign(dlat), linewidth=4,color=gr,head_width=arwid) 
               axs[0].text(arx0+0.4*arxd,ary0+aryd*1.2*np.sign(dlat),'Vsat',fontsize=fs1,color=gr)
               axs[0].arrow(arx0, ary0 ,  arxd*Look, 0, linewidth=4,color=gr,head_width=arwid) 
               axs[0].text(arx0+arxd*(1.5*Look-0.5),ary0-2,'Look',fontsize=fs1,color=gr)
        
               _=axs[0].set_xlabel('cross-track (km)', fontsize=fs1)
               _=axs[0].set_title('sea level, track '+tracks+' '+cycle+', '+latcs+' '+loncs)
               axs[0].set_xlim((X[I1],X[I2]))
               axs[0].set_ylim((YP[J1],YP[J2]))
  # Now changes the labels to the distance alongtrack 
               Yticks=axs[0].get_yticks()
               newlabs=[ f"{int(np.abs(value)):04d}" for value in Yticks ]
               axs[0].set_yticklabels(newlabs)
    
      
               im=axs[1].pcolormesh(X[I1:I2],YP[J1:J2],SIG0,cmap='Greys_r',rasterized=True,vmax=sig0mean+2.5*sig0std,vmin=sig0mean-2.5*sig0std)
               axs[1].set_xlim((X[I1],X[I2]))
               axs[1].set_ylim((YP[J1],YP[J2]))
               _=axs[1].set_xlabel('cross-track (km)', fontsize=fs1)
               _=axs[1].set_title(r' $\sigma_0$, median='+f'{abs(sig0mean):4.1f}'+'dB, std='+f'{abs(sig0std):4.1f}'+'dB')
               axs[1].set_yticklabels(np.abs(Yticks).astype(str))

            if (HsvalueOK ==1):
               axs[1].add_patch(Rectangle((arx0-4.5*arxd,ary0-2.0*aryd),arxd*10,aryd*3.4,facecolor="white",alpha=0.5) )
               resultat1=r'total $H_{s}$ model='+f'{Hs:4.2f}'+' m, $Q_{kk}$ model ='+f'{Qkk:4.0f}'+' m'
               axs[1].text(arx0-4*arxd,ary0+0.8*aryd, resultat1,fontsize=16,color='k')
               resultat1=r'$H_{18}$ SWOT='+f'{Hs_SWOT_mask:4.2f}'+' m, $H_{18}$ model = '+f'{Hs_WW3_mask:4.2f}'+' m'
               axs[1].text(arx0-4*arxd,ary0, resultat1,fontsize=16,color='k')
               resultat2=r'$L_{18}$ SWOT='+f'{Lm_SWOT:4.0f}'+' m, $L_{18}$ model = '+f'{Lm_WW3:4.0f}'+' m'
               axs[1].text(arx0-4*arxd,ary0-0.8*aryd, resultat2,fontsize=16,color='k')
               resultat3=r'$\theta_{18}$ SWOT='+f'{dm_SWOT:3.0f}'+r' deg, $\theta_{18}$ model= '+f'{dm_WW3:3.0f}'+' deg'
               axs[1].text(arx0-4*arxd,ary0-1.6*aryd, resultat3,fontsize=16,color='k')
#  print('Hs from SWOT :',Hs_SWOT, Hs_SWOT_all, Hs_SWOT_mask,' and WW3:',Hs_WW3,Hs_WW3_all,Hs_WW3_mask,'##',Hs_WW3_cut )
#  print('Lm,dm from SWOT:',Lm_SWOT,dm_SWOT,' and WW3:',Lm_WW3,dm_WW3,shiftdir,ncoh )


            if savefile=='pdf' :    
               fig.savefig(pth_results+filetag+'map.pdf') #',dpi=100)
            else :
               fig.savefig(pth_results+filetag+'map.png',dpi=100)

print(SL3_nc)
SL3_nc.close()  # close the L3 spectra file
# Out:
# Reading file: /media/ardhuin/FabLinux/SWOT2/SWOT_L3_LR_SSH_Unsmoothed_002_485_20230828T091915_20230828T101042_v1.0.1.nc ## 20230828T091915_20230828T101042_v1.0.1.nc
# file for model: /media/ardhuin/FabLinux/WW3-SWOT/GLOBAL_REF102040/SWOT_WW3-GLOB-30M_202308_trck.nc
# track vector: 29364 0.8464199999999984 0.1480981596829615 -170.07541886494005 9.924581135059952 ## 0.8464199999999984 1 29238
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6990030900811198 72 20.4891
# /tmp/ipykernel_6810/798719996.py:349: RuntimeWarning: divide by zero encountered in log10
#   im=ax[1].pcolormesh(-kxm[ix1:ix1+nxtile*6]*1000,-kym[iy1:iy1+nxtile*6]*1000,10*np.log10(Ekxky[ix1:ix1+nxtile*6,iy1:iy1+nxtile*6]).T,cmap='viridis',rasterized=True,vmin=-10+dBE2, vmax=30+dBE2)
# sres: 40
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:42.199342080
# Writing to file for latitude  -25.015030000000003  in range [ -25 -10 ] , indices: 0 0 40 ## 0 0 , size: (1, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9530986516366742 536 19.503550000000004
# sres: 20
# Writing to file for latitude  -25.0877  in range [ -25 -10 ] , indices: 0 0 20 ## 0 0 , size: (1, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9834200466114309 522 20.11325
# sres: 20
# Writing to file for latitude  -24.99913  in range [ -25 -10 ] , indices: 0 0 20 ## 1 0 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.103620000000003  in range [ -25 -10 ] , indices: 0 0 20 ## 0 1 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.015030000000003  in range [ -25 -10 ] , indices: 0 0 20 ## 1 1 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.11945  in range [ -25 -10 ] , indices: 0 0 20 ## 0 2 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.03084  in range [ -25 -10 ] , indices: 0 0 20 ## 1 2 , size: (1, 2, 6, 42, 40)
# /tmp/ipykernel_6810/798719996.py:485: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_yticklabels(newlabs)
# /tmp/ipykernel_6810/798719996.py:493: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_yticklabels(np.abs(Yticks).astype(str))
# track vector: 29364 0.8464199999999984 0.1480981596829615 -170.07541886494005 9.924581135059952 ## 0.8464199999999984 1 29238
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6688438258666428 76 21.8976
# /tmp/ipykernel_6810/798719996.py:349: RuntimeWarning: divide by zero encountered in log10
#   im=ax[1].pcolormesh(-kxm[ix1:ix1+nxtile*6]*1000,-kym[iy1:iy1+nxtile*6]*1000,10*np.log10(Ekxky[ix1:ix1+nxtile*6,iy1:iy1+nxtile*6]).T,cmap='viridis',rasterized=True,vmin=-10+dBE2, vmax=30+dBE2)
# sres: 40
# Writing to file for latitude  -25.101070000000004  in range [ -25 -10 ] , indices: 0 1 40 ## 0 0 , size: (1, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9520081623046962 483 22.921950000000002
# sres: 20
# Writing to file for latitude  -25.174220000000002  in range [ -25 -10 ] , indices: 0 1 20 ## 0 0 , size: (1, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9711700400003384 453 22.283749999999998
# sres: 20
# Writing to file for latitude  -25.08554  in range [ -25 -10 ] , indices: 0 1 20 ## 1 0 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.189760000000003  in range [ -25 -10 ] , indices: 0 1 20 ## 0 1 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.101070000000004  in range [ -25 -10 ] , indices: 0 1 20 ## 1 1 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.205240000000003  in range [ -25 -10 ] , indices: 0 1 20 ## 0 2 , size: (1, 2, 6, 42, 40)
# sres: 20
# Writing to file for latitude  -25.11653  in range [ -25 -10 ] , indices: 0 1 20 ## 1 2 , size: (1, 2, 6, 42, 40)
# track vector: 29448 0.8464500000000008 0.1477131392051491 -170.10105329896604 9.898946701033964 ## 0.8464500000000008 1 29322
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6664000198996385 78 21.250149999999998
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:45.319384448
# Writing to file for latitude  -24.83789  in range [ -25 -10 ] , indices: 1 0 40 ## 0 0 , size: (2, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9584463487690579 558 20.261850000000003
# Writing to file for latitude  -24.910590000000003  in range [ -25 -10 ] , indices: 1 0 20 ## 0 0 , size: (2, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9514259124459553 547 20.598950000000002
# Writing to file for latitude  -24.82203  in range [ -25 -10 ] , indices: 1 0 20 ## 1 0 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.926470000000002  in range [ -25 -10 ] , indices: 1 0 20 ## 0 1 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.83789  in range [ -25 -10 ] , indices: 1 0 20 ## 1 1 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.94227  in range [ -25 -10 ] , indices: 1 0 20 ## 0 2 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.85367  in range [ -25 -10 ] , indices: 1 0 20 ## 1 2 , size: (2, 2, 6, 42, 40)
# track vector: 29448 0.8464500000000008 0.1477131392051491 -170.10105329896604 9.898946701033964 ## 0.8464500000000008 1 29322
# Swell mask option: 7 1 -5 0.3 0.639803852625638 74 22.0841
# Writing to file for latitude  -24.92366  in range [ -25 -10 ] , indices: 1 1 40 ## 0 0 , size: (2, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.8984307068275142 478 21.8318
# Writing to file for latitude  -24.99686  in range [ -25 -10 ] , indices: 1 1 20 ## 0 0 , size: (2, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9462326025559439 387 22.0709
# Writing to file for latitude  -24.90818  in range [ -25 -10 ] , indices: 1 1 20 ## 1 0 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -25.01237  in range [ -25 -10 ] , indices: 1 1 20 ## 0 1 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.92366  in range [ -25 -10 ] , indices: 1 1 20 ## 1 1 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -25.027810000000002  in range [ -25 -10 ] , indices: 1 1 20 ## 0 2 , size: (2, 2, 6, 42, 40)
# Writing to file for latitude  -24.939090000000004  in range [ -25 -10 ] , indices: 1 1 20 ## 1 2 , size: (2, 2, 6, 42, 40)
# track vector: 29532 0.8465099999999985 0.14729767951214914 -170.12903264946482 9.870967350535182 ## 0.8465099999999985 1 29406
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6561370010500076 80 22.7692
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:48.439426688
# Writing to file for latitude  -24.660670000000003  in range [ -25 -10 ] , indices: 2 0 40 ## 0 0 , size: (3, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9777129328236284 524 21.1643
# Writing to file for latitude  -24.73344  in range [ -25 -10 ] , indices: 2 0 20 ## 0 0 , size: (3, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.969461537229513 586 22.5565
# Writing to file for latitude  -24.64486  in range [ -25 -10 ] , indices: 2 0 20 ## 1 0 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.749280000000002  in range [ -25 -10 ] , indices: 2 0 20 ## 0 1 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.660670000000003  in range [ -25 -10 ] , indices: 2 0 20 ## 1 1 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.765040000000003  in range [ -25 -10 ] , indices: 2 0 20 ## 0 2 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.67642  in range [ -25 -10 ] , indices: 2 0 20 ## 1 2 , size: (3, 2, 6, 42, 40)
# track vector: 29532 0.8465099999999985 0.14729767951214914 -170.12903264946482 9.870967350535182 ## 0.8465099999999985 1 29406
# Swell mask option: 7 1 -5 0.3 0.6498972254073913 88 23.417749999999998
# Writing to file for latitude  -24.7463  in range [ -25 -10 ] , indices: 2 1 40 ## 0 0 , size: (3, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.925966851161303 428 23.3191
# Writing to file for latitude  -24.819490000000002  in range [ -25 -10 ] , indices: 2 1 20 ## 0 0 , size: (3, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.90847652694322 537 24.45095
# Writing to file for latitude  -24.73084  in range [ -25 -10 ] , indices: 2 1 20 ## 1 0 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.834950000000003  in range [ -25 -10 ] , indices: 2 1 20 ## 0 1 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.7463  in range [ -25 -10 ] , indices: 2 1 20 ## 1 1 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.850360000000002  in range [ -25 -10 ] , indices: 2 1 20 ## 0 2 , size: (3, 2, 6, 42, 40)
# Writing to file for latitude  -24.76169  in range [ -25 -10 ] , indices: 2 1 20 ## 1 2 , size: (3, 2, 6, 42, 40)
# track vector: 29616 0.8464799999999997 0.14717929986293465 -170.13646715716612 9.863532842833877 ## 0.8464799999999997 1 29490
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6785285917337476 80 23.28815
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:51.559468928
# Writing to file for latitude  -24.48347  in range [ -25 -10 ] , indices: 3 0 40 ## 0 0 , size: (4, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9602532694395747 571 22.668550000000003
# Writing to file for latitude  -24.556250000000002  in range [ -25 -10 ] , indices: 3 0 20 ## 0 0 , size: (4, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9613195746144538 527 21.8058
# Writing to file for latitude  -24.4677  in range [ -25 -10 ] , indices: 3 0 20 ## 1 0 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.57205  in range [ -25 -10 ] , indices: 3 0 20 ## 0 1 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.48347  in range [ -25 -10 ] , indices: 3 0 20 ## 1 1 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.587770000000003  in range [ -25 -10 ] , indices: 3 0 20 ## 0 2 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.499170000000003  in range [ -25 -10 ] , indices: 3 0 20 ## 1 2 , size: (4, 2, 6, 42, 40)
# track vector: 29616 0.8464799999999997 0.14717929986293465 -170.13646715716612 9.863532842833877 ## 0.8464799999999997 1 29490
# Swell mask option: 7 1 -5 0.3 0.6364214788743001 82 23.6321
# Writing to file for latitude  -24.568900000000003  in range [ -25 -10 ] , indices: 3 1 40 ## 0 0 , size: (4, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9197844593594224 501 25.084600000000002
# Writing to file for latitude  -24.64214  in range [ -25 -10 ] , indices: 3 1 20 ## 0 0 , size: (4, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9122891470464732 471 24.791500000000003
# Writing to file for latitude  -24.55348  in range [ -25 -10 ] , indices: 3 1 20 ## 1 0 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.657580000000003  in range [ -25 -10 ] , indices: 3 1 20 ## 0 1 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.568900000000003  in range [ -25 -10 ] , indices: 3 1 20 ## 1 1 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.672950000000004  in range [ -25 -10 ] , indices: 3 1 20 ## 0 2 , size: (4, 2, 6, 42, 40)
# Writing to file for latitude  -24.58425  in range [ -25 -10 ] , indices: 3 1 20 ## 1 2 , size: (4, 2, 6, 42, 40)
# track vector: 29700 0.8464899999999993 0.14682177817123515 -170.1600722881363 9.839927711863709 ## 0.8464899999999993 1 29574
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6343685972715706 78 21.905950000000004
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:54.678638592
# Writing to file for latitude  -24.306250000000002  in range [ -25 -10 ] , indices: 4 0 40 ## 0 0 , size: (5, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9547780132841246 544 21.5573
# Writing to file for latitude  -24.3791  in range [ -25 -10 ] , indices: 4 0 20 ## 0 0 , size: (5, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9522667822282306 464 21.24125
# Writing to file for latitude  -24.29052  in range [ -25 -10 ] , indices: 4 0 20 ## 1 0 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.39485  in range [ -25 -10 ] , indices: 4 0 20 ## 0 1 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.306250000000002  in range [ -25 -10 ] , indices: 4 0 20 ## 1 1 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.41053  in range [ -25 -10 ] , indices: 4 0 20 ## 0 2 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.321910000000003  in range [ -25 -10 ] , indices: 4 0 20 ## 1 2 , size: (5, 2, 6, 42, 40)
# track vector: 29700 0.8464899999999993 0.14682177817123515 -170.1600722881363 9.839927711863709 ## 0.8464899999999993 1 29574
# Swell mask option: 7 1 -5 0.3 0.6521994090260782 82 22.5009
# Writing to file for latitude  -24.39148  in range [ -25 -10 ] , indices: 4 1 40 ## 0 0 , size: (5, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9460574219979772 480 24.023400000000002
# Writing to file for latitude  -24.46477  in range [ -25 -10 ] , indices: 4 1 20 ## 0 0 , size: (5, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.939751125264804 479 23.482350000000004
# Writing to file for latitude  -24.3761  in range [ -25 -10 ] , indices: 4 1 20 ## 1 0 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.48017  in range [ -25 -10 ] , indices: 4 1 20 ## 0 1 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.39148  in range [ -25 -10 ] , indices: 4 1 20 ## 1 1 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.495500000000003  in range [ -25 -10 ] , indices: 4 1 20 ## 0 2 , size: (5, 2, 6, 42, 40)
# Writing to file for latitude  -24.40679  in range [ -25 -10 ] , indices: 4 1 20 ## 1 2 , size: (5, 2, 6, 42, 40)
# track vector: 29784 0.8465899999999991 0.14642477064808257 -170.18729819268873 9.81270180731127 ## 0.8465899999999991 1 29658
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.7433128358614213 70 20.796200000000002
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:37:57.797229312
# Writing to file for latitude  -24.129070000000002  in range [ -25 -10 ] , indices: 5 0 40 ## 0 0 , size: (6, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9740465328527983 494 20.753800000000002
# Writing to file for latitude  -24.201960000000003  in range [ -25 -10 ] , indices: 5 0 20 ## 0 0 , size: (6, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9702297047873764 528 20.72445
# Writing to file for latitude  -24.113370000000003  in range [ -25 -10 ] , indices: 5 0 20 ## 1 0 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.217670000000002  in range [ -25 -10 ] , indices: 5 0 20 ## 0 1 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.129070000000002  in range [ -25 -10 ] , indices: 5 0 20 ## 1 1 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.233300000000003  in range [ -25 -10 ] , indices: 5 0 20 ## 0 2 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.14468  in range [ -25 -10 ] , indices: 5 0 20 ## 1 2 , size: (6, 2, 6, 42, 40)
# track vector: 29784 0.8465899999999991 0.14642477064808257 -170.18729819268873 9.81270180731127 ## 0.8465899999999991 1 29658
# Swell mask option: 7 1 -5 0.3 0.6650640985201087 82 20.927750000000003
# Writing to file for latitude  -24.21411  in range [ -25 -10 ] , indices: 5 1 40 ## 0 0 , size: (6, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9531436825488002 481 22.4784
# Writing to file for latitude  -24.287480000000002  in range [ -25 -10 ] , indices: 5 1 20 ## 0 0 , size: (6, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9336092535956907 530 21.4962
# Writing to file for latitude  -24.198780000000003  in range [ -25 -10 ] , indices: 5 1 20 ## 1 0 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.302830000000004  in range [ -25 -10 ] , indices: 5 1 20 ## 0 1 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.21411  in range [ -25 -10 ] , indices: 5 1 20 ## 1 1 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.31812  in range [ -25 -10 ] , indices: 5 1 20 ## 0 2 , size: (6, 2, 6, 42, 40)
# Writing to file for latitude  -24.229390000000002  in range [ -25 -10 ] , indices: 5 1 20 ## 1 2 , size: (6, 2, 6, 42, 40)
# track vector: 29868 0.84666 0.14607035608873029 -170.2113830210905 9.788616978909488 ## 0.84666 1 29742
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.7684625225931373 74 20.1826
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:00.915820288
# Writing to file for latitude  -23.951880000000003  in range [ -25 -10 ] , indices: 6 0 40 ## 0 0 , size: (7, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9741640745817259 504 20.235350000000004
# Writing to file for latitude  -24.024820000000002  in range [ -25 -10 ] , indices: 6 0 20 ## 0 0 , size: (7, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9810211714643553 466 19.645400000000002
# Writing to file for latitude  -23.936230000000002  in range [ -25 -10 ] , indices: 6 0 20 ## 1 0 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.040490000000002  in range [ -25 -10 ] , indices: 6 0 20 ## 0 1 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -23.951880000000003  in range [ -25 -10 ] , indices: 6 0 20 ## 1 1 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.05609  in range [ -25 -10 ] , indices: 6 0 20 ## 0 2 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -23.967460000000003  in range [ -25 -10 ] , indices: 6 0 20 ## 1 2 , size: (7, 2, 6, 42, 40)
# track vector: 29868 0.84666 0.14607035608873029 -170.2113830210905 9.788616978909488 ## 0.84666 1 29742
# Swell mask option: 7 1 -5 0.3 0.7315869355791869 76 20.56935
# Writing to file for latitude  -24.03665  in range [ -25 -10 ] , indices: 6 1 40 ## 0 0 , size: (7, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9668948480509295 480 21.0201
# Writing to file for latitude  -24.110080000000004  in range [ -25 -10 ] , indices: 6 1 20 ## 0 0 , size: (7, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9631990322550554 512 20.934600000000003
# Writing to file for latitude  -24.02136  in range [ -25 -10 ] , indices: 6 1 20 ## 1 0 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.125390000000003  in range [ -25 -10 ] , indices: 6 1 20 ## 0 1 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.03665  in range [ -25 -10 ] , indices: 6 1 20 ## 1 1 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.14064  in range [ -25 -10 ] , indices: 6 1 20 ## 0 2 , size: (7, 2, 6, 42, 40)
# Writing to file for latitude  -24.05189  in range [ -25 -10 ] , indices: 6 1 20 ## 1 2 , size: (7, 2, 6, 42, 40)
# track vector: 29952 0.8467900000000022 0.14571299439772656 -170.23633959154603 9.763660408453973 ## 0.8467900000000022 1 29826
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.7377292215787734 64 20.4203
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:04.034411008
# Writing to file for latitude  -23.774630000000002  in range [ -25 -10 ] , indices: 7 0 40 ## 0 0 , size: (8, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9814912262542527 437 19.55515
# Writing to file for latitude  -23.847630000000002  in range [ -25 -10 ] , indices: 7 0 20 ## 0 0 , size: (8, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9565886066981261 535 19.71015
# Writing to file for latitude  -23.759020000000003  in range [ -25 -10 ] , indices: 7 0 20 ## 1 0 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.863270000000004  in range [ -25 -10 ] , indices: 7 0 20 ## 0 1 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.774630000000002  in range [ -25 -10 ] , indices: 7 0 20 ## 1 1 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.87882  in range [ -25 -10 ] , indices: 7 0 20 ## 0 2 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.790170000000003  in range [ -25 -10 ] , indices: 7 0 20 ## 1 2 , size: (8, 2, 6, 42, 40)
# track vector: 29952 0.8467900000000022 0.14571299439772656 -170.23633959154603 9.763660408453973 ## 0.8467900000000022 1 29826
# Swell mask option: 7 1 -5 0.3 0.7244133663499033 84 21.31335
# Writing to file for latitude  -23.85921  in range [ -25 -10 ] , indices: 7 1 40 ## 0 0 , size: (8, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9678658433674545 503 21.329700000000003
# Writing to file for latitude  -23.932640000000003  in range [ -25 -10 ] , indices: 7 1 20 ## 0 0 , size: (8, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9788858977218828 488 21.94195
# Writing to file for latitude  -23.843940000000003  in range [ -25 -10 ] , indices: 7 1 20 ## 1 0 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.94791  in range [ -25 -10 ] , indices: 7 1 20 ## 0 1 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.85921  in range [ -25 -10 ] , indices: 7 1 20 ## 1 1 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.963140000000003  in range [ -25 -10 ] , indices: 7 1 20 ## 0 2 , size: (8, 2, 6, 42, 40)
# Writing to file for latitude  -23.87441  in range [ -25 -10 ] , indices: 7 1 20 ## 1 2 , size: (8, 2, 6, 42, 40)
# track vector: 30036 0.8468599999999995 0.14519703358931835 -170.27103901714003 9.728960982859974 ## 0.8468599999999995 1 29910
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.7051165537644418 74 21.49595
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:07.153001984
# Writing to file for latitude  -23.597330000000003  in range [ -25 -10 ] , indices: 8 0 40 ## 0 0 , size: (9, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.958859372787617 525 20.4193
# Writing to file for latitude  -23.67039  in range [ -25 -10 ] , indices: 8 0 20 ## 0 0 , size: (9, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9605622447076684 483 21.26025
# Writing to file for latitude  -23.581750000000003  in range [ -25 -10 ] , indices: 8 0 20 ## 1 0 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.68598  in range [ -25 -10 ] , indices: 8 0 20 ## 0 1 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.597330000000003  in range [ -25 -10 ] , indices: 8 0 20 ## 1 1 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.701510000000003  in range [ -25 -10 ] , indices: 8 0 20 ## 0 2 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.612840000000002  in range [ -25 -10 ] , indices: 8 0 20 ## 1 2 , size: (9, 2, 6, 42, 40)
# track vector: 30036 0.8468599999999995 0.14519703358931835 -170.27103901714003 9.728960982859974 ## 0.8468599999999995 1 29910
# Swell mask option: 7 1 -5 0.3 0.7111622397138145 92 22.35785
# Writing to file for latitude  -23.681720000000002  in range [ -25 -10 ] , indices: 8 1 40 ## 0 0 , size: (9, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.956485987840169 561 22.4996
# Writing to file for latitude  -23.75523  in range [ -25 -10 ] , indices: 8 1 20 ## 0 0 , size: (9, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9561359044928243 495 22.94775
# Writing to file for latitude  -23.666500000000003  in range [ -25 -10 ] , indices: 8 1 20 ## 1 0 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.770480000000003  in range [ -25 -10 ] , indices: 8 1 20 ## 0 1 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.681720000000002  in range [ -25 -10 ] , indices: 8 1 20 ## 1 1 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.785670000000003  in range [ -25 -10 ] , indices: 8 1 20 ## 0 2 , size: (9, 2, 6, 42, 40)
# Writing to file for latitude  -23.696890000000003  in range [ -25 -10 ] , indices: 8 1 20 ## 1 2 , size: (9, 2, 6, 42, 40)
# track vector: 30120 0.84694 0.14474198949985817 -170.30184806477598 9.698151935224018 ## 0.84694 1 29994
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.7317269187397953 56 22.290750000000003
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:10.271156480
# Writing to file for latitude  -23.42002  in range [ -25 -10 ] , indices: 9 0 40 ## 0 0 , size: (10, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9714451563900702 580 21.6635
# Writing to file for latitude  -23.493100000000002  in range [ -25 -10 ] , indices: 9 0 20 ## 0 0 , size: (10, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9922667941218047 396 22.45175
# Writing to file for latitude  -23.40446  in range [ -25 -10 ] , indices: 9 0 20 ## 1 0 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.508670000000002  in range [ -25 -10 ] , indices: 9 0 20 ## 0 1 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.42002  in range [ -25 -10 ] , indices: 9 0 20 ## 1 1 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.52417  in range [ -25 -10 ] , indices: 9 0 20 ## 0 2 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.43551  in range [ -25 -10 ] , indices: 9 0 20 ## 1 2 , size: (10, 2, 6, 42, 40)
# track vector: 30120 0.84694 0.14474198949985817 -170.30184806477598 9.698151935224018 ## 0.84694 1 29994
# Swell mask option: 7 1 -5 0.3 0.7145331898547171 86 22.856450000000002
# Writing to file for latitude  -23.504240000000003  in range [ -25 -10 ] , indices: 9 1 40 ## 0 0 , size: (10, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9792782263530867 481 23.36365
# Writing to file for latitude  -23.57777  in range [ -25 -10 ] , indices: 9 1 20 ## 0 0 , size: (10, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9642950586413609 481 23.663850000000004
# Writing to file for latitude  -23.489050000000002  in range [ -25 -10 ] , indices: 9 1 20 ## 1 0 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.59298  in range [ -25 -10 ] , indices: 9 1 20 ## 0 1 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.504240000000003  in range [ -25 -10 ] , indices: 9 1 20 ## 1 1 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.608140000000002  in range [ -25 -10 ] , indices: 9 1 20 ## 0 2 , size: (10, 2, 6, 42, 40)
# Writing to file for latitude  -23.51938  in range [ -25 -10 ] , indices: 9 1 20 ## 1 2 , size: (10, 2, 6, 42, 40)
# track vector: 30204 0.8470000000000013 0.14444911053781503 -170.32177293633023 9.678227063669766 ## 0.8470000000000013 1 30078
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6203003008722632 64 22.7815
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:13.389021440
# Writing to file for latitude  -23.242800000000003  in range [ -25 -10 ] , indices: 10 0 40 ## 0 0 , size: (11, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9506295400583545 439 23.35395
# Writing to file for latitude  -23.31586  in range [ -25 -10 ] , indices: 10 0 20 ## 0 0 , size: (11, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.896046047223884 501 22.8745
# Writing to file for latitude  -23.227290000000004  in range [ -25 -10 ] , indices: 10 0 20 ## 1 0 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.331400000000002  in range [ -25 -10 ] , indices: 10 0 20 ## 0 1 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.242800000000003  in range [ -25 -10 ] , indices: 10 0 20 ## 1 1 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.346870000000003  in range [ -25 -10 ] , indices: 10 0 20 ## 0 2 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.25824  in range [ -25 -10 ] , indices: 10 0 20 ## 1 2 , size: (11, 2, 6, 42, 40)
# track vector: 30204 0.8470000000000013 0.14444911053781503 -170.32177293633023 9.678227063669766 ## 0.8470000000000013 1 30078
# Swell mask option: 7 1 -5 0.3 0.6731213557648269 66 23.310100000000002
# Writing to file for latitude  -23.326800000000002  in range [ -25 -10 ] , indices: 10 1 40 ## 0 0 , size: (11, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9669512499874574 508 23.3872
# Writing to file for latitude  -23.400360000000003  in range [ -25 -10 ] , indices: 10 1 20 ## 0 0 , size: (11, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9481434951864973 464 24.14895
# Writing to file for latitude  -23.31164  in range [ -25 -10 ] , indices: 10 1 20 ## 1 0 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.41553  in range [ -25 -10 ] , indices: 10 1 20 ## 0 1 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.326800000000002  in range [ -25 -10 ] , indices: 10 1 20 ## 1 1 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.430650000000004  in range [ -25 -10 ] , indices: 10 1 20 ## 0 2 , size: (11, 2, 6, 42, 40)
# Writing to file for latitude  -23.341900000000003  in range [ -25 -10 ] , indices: 10 1 20 ## 1 2 , size: (11, 2, 6, 42, 40)
# track vector: 30288 0.8470699999999987 0.1440248286447501 -170.35044735992545 9.649552640074546 ## 0.8470699999999987 1 30162
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6519273849801768 90 23.4497
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:16.506886400
# Writing to file for latitude  -23.06557  in range [ -25 -10 ] , indices: 11 0 40 ## 0 0 , size: (12, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9602053571339867 442 22.2928
# Writing to file for latitude  -23.138730000000002  in range [ -25 -10 ] , indices: 11 0 20 ## 0 0 , size: (12, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9399325677868069 358 22.5542
# Writing to file for latitude  -23.0501  in range [ -25 -10 ] , indices: 11 0 20 ## 1 0 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.154210000000003  in range [ -25 -10 ] , indices: 11 0 20 ## 0 1 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.06557  in range [ -25 -10 ] , indices: 11 0 20 ## 1 1 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.169620000000002  in range [ -25 -10 ] , indices: 11 0 20 ## 0 2 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.08097  in range [ -25 -10 ] , indices: 11 0 20 ## 1 2 , size: (12, 2, 6, 42, 40)
# track vector: 30288 0.8470699999999987 0.1440248286447501 -170.35044735992545 9.649552640074546 ## 0.8470699999999987 1 30162
# Swell mask option: 7 1 -5 0.3 0.6388893150660482 70 22.67655
# Writing to file for latitude  -23.14929  in range [ -25 -10 ] , indices: 11 1 40 ## 0 0 , size: (12, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9125887254904441 455 25.12685
# Writing to file for latitude  -23.222900000000003  in range [ -25 -10 ] , indices: 11 1 20 ## 0 0 , size: (12, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.948213328063364 454 24.5621
# Writing to file for latitude  -23.13417  in range [ -25 -10 ] , indices: 11 1 20 ## 1 0 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.23804  in range [ -25 -10 ] , indices: 11 1 20 ## 0 1 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.14929  in range [ -25 -10 ] , indices: 11 1 20 ## 1 1 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.253130000000002  in range [ -25 -10 ] , indices: 11 1 20 ## 0 2 , size: (12, 2, 6, 42, 40)
# Writing to file for latitude  -23.164360000000002  in range [ -25 -10 ] , indices: 11 1 20 ## 1 2 , size: (12, 2, 6, 42, 40)
# track vector: 30372 0.8470900000000015 0.14384615542187565 -170.36241693728704 9.637583062712963 ## 0.8470900000000015 1 30246
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6379642205623102 92 22.866950000000003
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:19.624751360
# Writing to file for latitude  -22.888230000000004  in range [ -25 -10 ] , indices: 12 0 40 ## 0 0 , size: (13, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9754363419890323 475 23.78315
# Writing to file for latitude  -22.961440000000003  in range [ -25 -10 ] , indices: 12 0 20 ## 0 0 , size: (13, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9564301478561456 438 23.063200000000002
# Writing to file for latitude  -22.8728  in range [ -25 -10 ] , indices: 12 0 20 ## 1 0 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.97688  in range [ -25 -10 ] , indices: 12 0 20 ## 0 1 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.888230000000004  in range [ -25 -10 ] , indices: 12 0 20 ## 1 1 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.99226  in range [ -25 -10 ] , indices: 12 0 20 ## 0 2 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.90358  in range [ -25 -10 ] , indices: 12 0 20 ## 1 2 , size: (13, 2, 6, 42, 40)
# track vector: 30372 0.8470900000000015 0.14384615542187565 -170.36241693728704 9.637583062712963 ## 0.8470900000000015 1 30246
# Swell mask option: 7 1 -5 0.3 0.6667608280077235 86 21.73525
# Writing to file for latitude  -22.9718  in range [ -25 -10 ] , indices: 12 1 40 ## 0 0 , size: (13, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9247574724162644 502 22.599450000000004
# Writing to file for latitude  -23.045420000000004  in range [ -25 -10 ] , indices: 12 1 20 ## 0 0 , size: (13, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9642800403950148 485 22.24595
# Writing to file for latitude  -22.95671  in range [ -25 -10 ] , indices: 12 1 20 ## 1 0 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -23.060530000000004  in range [ -25 -10 ] , indices: 12 1 20 ## 0 1 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.9718  in range [ -25 -10 ] , indices: 12 1 20 ## 1 1 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -23.075580000000002  in range [ -25 -10 ] , indices: 12 1 20 ## 0 2 , size: (13, 2, 6, 42, 40)
# Writing to file for latitude  -22.98683  in range [ -25 -10 ] , indices: 12 1 20 ## 1 2 , size: (13, 2, 6, 42, 40)
# track vector: 30456 0.8470699999999987 0.14347151491854235 -170.38682583970774 9.61317416029226 ## 0.8470699999999987 1 30330
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6857169276506824 82 21.701349999999998
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:22.742616576
# Writing to file for latitude  -22.71092  in range [ -25 -10 ] , indices: 13 0 40 ## 0 0 , size: (14, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9168351849236953 490 21.60115
# Writing to file for latitude  -22.784160000000004  in range [ -25 -10 ] , indices: 13 0 20 ## 0 0 , size: (14, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9396739115745122 497 20.7633
# Writing to file for latitude  -22.69553  in range [ -25 -10 ] , indices: 13 0 20 ## 1 0 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.799570000000003  in range [ -25 -10 ] , indices: 13 0 20 ## 0 1 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.71092  in range [ -25 -10 ] , indices: 13 0 20 ## 1 1 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.8149  in range [ -25 -10 ] , indices: 13 0 20 ## 0 2 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.72624  in range [ -25 -10 ] , indices: 13 0 20 ## 1 2 , size: (14, 2, 6, 42, 40)
# track vector: 30456 0.8470699999999987 0.14347151491854235 -170.38682583970774 9.61317416029226 ## 0.8470699999999987 1 30330
# Swell mask option: 7 1 -5 0.3 0.7347480966068795 82 22.2742
# Writing to file for latitude  -22.794240000000002  in range [ -25 -10 ] , indices: 13 1 40 ## 0 0 , size: (14, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9633295012131565 495 22.405450000000002
# Writing to file for latitude  -22.86793  in range [ -25 -10 ] , indices: 13 1 20 ## 0 0 , size: (14, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9681220513525084 468 22.6719
# Writing to file for latitude  -22.77918  in range [ -25 -10 ] , indices: 13 1 20 ## 1 0 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.883000000000003  in range [ -25 -10 ] , indices: 13 1 20 ## 0 1 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.794240000000002  in range [ -25 -10 ] , indices: 13 1 20 ## 1 1 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.898020000000002  in range [ -25 -10 ] , indices: 13 1 20 ## 0 2 , size: (14, 2, 6, 42, 40)
# Writing to file for latitude  -22.809240000000003  in range [ -25 -10 ] , indices: 13 1 20 ## 1 2 , size: (14, 2, 6, 42, 40)
# track vector: 30540 0.8470699999999987 0.14318639859387056 -170.4055743171636 9.594425682836402 ## 0.8470699999999987 1 30414
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6986643332248069 76 21.814149999999998
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:25.859954688
# Writing to file for latitude  -22.53359  in range [ -25 -10 ] , indices: 14 0 40 ## 0 0 , size: (15, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9649002782982266 463 20.4185
# Writing to file for latitude  -22.60687  in range [ -25 -10 ] , indices: 14 0 20 ## 0 0 , size: (15, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9848722893553867 460 20.3488
# Writing to file for latitude  -22.518230000000003  in range [ -25 -10 ] , indices: 14 0 20 ## 1 0 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.62224  in range [ -25 -10 ] , indices: 14 0 20 ## 0 1 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.53359  in range [ -25 -10 ] , indices: 14 0 20 ## 1 1 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.63754  in range [ -25 -10 ] , indices: 14 0 20 ## 0 2 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.54888  in range [ -25 -10 ] , indices: 14 0 20 ## 1 2 , size: (15, 2, 6, 42, 40)
# track vector: 30540 0.8470699999999987 0.14318639859387056 -170.4055743171636 9.594425682836402 ## 0.8470699999999987 1 30414
# Swell mask option: 7 1 -5 0.3 0.7366637997868518 66 22.688100000000002
# Writing to file for latitude  -22.6167  in range [ -25 -10 ] , indices: 14 1 40 ## 0 0 , size: (15, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9547374533537252 465 23.11085
# Writing to file for latitude  -22.690430000000003  in range [ -25 -10 ] , indices: 14 1 20 ## 0 0 , size: (15, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9662017853424542 464 23.4876
# Writing to file for latitude  -22.60168  in range [ -25 -10 ] , indices: 14 1 20 ## 1 0 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.705470000000002  in range [ -25 -10 ] , indices: 14 1 20 ## 0 1 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.6167  in range [ -25 -10 ] , indices: 14 1 20 ## 1 1 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.720450000000003  in range [ -25 -10 ] , indices: 14 1 20 ## 0 2 , size: (15, 2, 6, 42, 40)
# Writing to file for latitude  -22.631670000000003  in range [ -25 -10 ] , indices: 14 1 20 ## 1 2 , size: (15, 2, 6, 42, 40)
# track vector: 30624 0.8470999999999975 0.14275077152282548 -170.43455648985207 9.56544351014793 ## 0.8470999999999975 1 30498
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6910922825766356 70 22.44245
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:38:28.976368128
# Writing to file for latitude  -22.35628  in range [ -25 -10 ] , indices: 15 0 40 ## 0 0 , size: (16, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9627916883195196 508 21.0539
# Writing to file for latitude  -22.42961  in range [ -25 -10 ] , indices: 15 0 20 ## 0 0 , size: (16, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9714110755386659 478 21.86915
# Writing to file for latitude  -22.340970000000002  in range [ -25 -10 ] , indices: 15 0 20 ## 1 0 , size: (16, 2, 6, 42, 40)
# Writing to file for latitude  -22.444940000000003  in range [ -25 -10 ] , indices: 15 0 20 ## 0 1 , size: (16, 2, 6, 42, 40)
# Writing to file for latitude  -22.35628  in range [ -25 -10 ] , indices: 15 0 20 ## 1 1 , size: (16, 2, 6, 42, 40)
# Writing to file for latitude  -22.460210000000004  in range [ -25 -10 ] , indices: 15 0 20 ## 0 2 , size: (16, 2, 6, 42, 40)
# Writing to file for latitude  -22.371540000000003  in range [ -25 -10 ] , indices: 15 0 20 ## 1 2 , size: (16, 2, 6, 42, 40)
# track vector: 30624 0.8470999999999975 0.14275077152282548 -170.43455648985207 9.56544351014793 ## 0.8470999999999975 1 30498
# Swell mask option: 7 1 -5 0.3 0.6635703105308199 68 23.2814
# Writing to file for latitude  -22.43924  in range [ -25 -10 ] , indices: 15 1 40 ## 0 0 , size: (16, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9650294103105722 408 23.683
# Writing to file for latitude  -22.512980000000002  in range [ -25 -10 ] , indices: 15 1 20 ## 0 0 , size: (16, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.966870385766123 358 23.9921
# Writing to file for latitude  -22.42425  in range [ -25 -10 ] , indices: 15 1 20 ## 1 0 , size: (16, 2, 6, 42, 40)
# ...
# Writing to file for latitude  -9.85712  in range [ -25 -10 ] , indices: 86 0 20 ## 0 2 , size: (87, 2, 6, 42, 40)
# Writing to file for latitude  -9.76834  in range [ -25 -10 ] , indices: 86 0 20 ## 1 2 , size: (87, 2, 6, 42, 40)
# track vector: 36588 0.84802 0.12665434355057908 -171.5054916410711 8.494508358928897 ## 0.84802 1 36462
# Swell mask option: 7 1 -5 0.3 0.4377726973199068 22 25.508000000000003
# Writing to file for latitude  -9.828130000000002  in range [ -25 -10 ] , indices: 86 1 40 ## 0 0 , size: (87, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9128874635213673 244 25.762
# Writing to file for latitude  -9.90356  in range [ -25 -10 ] , indices: 86 1 20 ## 0 0 , size: (87, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9337278575001837 270 25.376649999999998
# Writing to file for latitude  -9.81474  in range [ -25 -10 ] , indices: 86 1 20 ## 1 0 , size: (87, 2, 6, 42, 40)
# Writing to file for latitude  -9.91695  in range [ -25 -10 ] , indices: 86 1 20 ## 0 1 , size: (87, 2, 6, 42, 40)
# Writing to file for latitude  -9.828130000000002  in range [ -25 -10 ] , indices: 86 1 20 ## 1 1 , size: (87, 2, 6, 42, 40)
# Writing to file for latitude  -9.93032  in range [ -25 -10 ] , indices: 86 1 20 ## 0 2 , size: (87, 2, 6, 42, 40)
# Writing to file for latitude  -9.84149  in range [ -25 -10 ] , indices: 86 1 20 ## 1 2 , size: (87, 2, 6, 42, 40)
# track vector: 36672 0.8479900000000011 0.12658353639887088 -171.5098753660307 8.490124633969288 ## 0.8479900000000011 1 36546
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.44342845982263485 24 27.781200000000002
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:42:12.899853824
# Writing to file for latitude  -9.577240000000002  in range [ -25 -10 ] , indices: 87 0 40 ## 0 0 , size: (88, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9293537296164516 250 27.93625
# Writing to file for latitude  -9.652500000000002  in range [ -25 -10 ] , indices: 87 0 20 ## 0 0 , size: (88, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9137764419421084 291 27.491950000000003
# Writing to file for latitude  -9.56372  in range [ -25 -10 ] , indices: 87 0 20 ## 1 0 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.666030000000001  in range [ -25 -10 ] , indices: 87 0 20 ## 0 1 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.577240000000002  in range [ -25 -10 ] , indices: 87 0 20 ## 1 1 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.67952  in range [ -25 -10 ] , indices: 87 0 20 ## 0 2 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.590720000000001  in range [ -25 -10 ] , indices: 87 0 20 ## 1 2 , size: (88, 2, 6, 42, 40)
# track vector: 36672 0.8479900000000011 0.12658353639887088 -171.5098753660307 8.490124633969288 ## 0.8479900000000011 1 36546
# Swell mask option: 7 1 -5 0.3 0.48154230799799846 26 25.151600000000002
# Writing to file for latitude  -9.65048  in range [ -25 -10 ] , indices: 87 1 40 ## 0 0 , size: (88, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.8298549430857733 296 25.279500000000002
# Writing to file for latitude  -9.72592  in range [ -25 -10 ] , indices: 87 1 20 ## 0 0 , size: (88, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9165676051248574 278 25.8872
# Writing to file for latitude  -9.6371  in range [ -25 -10 ] , indices: 87 1 20 ## 1 0 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.739310000000001  in range [ -25 -10 ] , indices: 87 1 20 ## 0 1 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.65048  in range [ -25 -10 ] , indices: 87 1 20 ## 1 1 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.75266  in range [ -25 -10 ] , indices: 87 1 20 ## 0 2 , size: (88, 2, 6, 42, 40)
# Writing to file for latitude  -9.66383  in range [ -25 -10 ] , indices: 87 1 20 ## 1 2 , size: (88, 2, 6, 42, 40)
# track vector: 36756 0.8479200000000002 0.12646204877985195 -171.51721506183185 8.482784938168152 ## 0.8479200000000002 1 36630
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.5184624631355 24 27.572850000000003
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:42:16.003929344
# Writing to file for latitude  -9.39968  in range [ -25 -10 ] , indices: 88 0 40 ## 0 0 , size: (89, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.8242174367123859 306 26.78405
# Writing to file for latitude  -9.474960000000001  in range [ -25 -10 ] , indices: 88 0 20 ## 0 0 , size: (89, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.8447193326646814 219 26.9052
# Writing to file for latitude  -9.386180000000001  in range [ -25 -10 ] , indices: 88 0 20 ## 1 0 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.48846  in range [ -25 -10 ] , indices: 88 0 20 ## 0 1 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.39968  in range [ -25 -10 ] , indices: 88 0 20 ## 1 1 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.501930000000002  in range [ -25 -10 ] , indices: 88 0 20 ## 0 2 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.41315  in range [ -25 -10 ] , indices: 88 0 20 ## 1 2 , size: (89, 2, 6, 42, 40)
# track vector: 36756 0.8479200000000002 0.12646204877985195 -171.51721506183185 8.482784938168152 ## 0.8479200000000002 1 36630
# Swell mask option: 7 1 -5 0.3 0.5466621512115508 22 25.431600000000003
# Writing to file for latitude  -9.47282  in range [ -25 -10 ] , indices: 88 1 40 ## 0 0 , size: (89, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9206465306735818 304 26.0831
# Writing to file for latitude  -9.54828  in range [ -25 -10 ] , indices: 88 1 20 ## 0 0 , size: (89, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.8719371937256739 334 25.94735
# Writing to file for latitude  -9.45946  in range [ -25 -10 ] , indices: 88 1 20 ## 1 0 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.56165  in range [ -25 -10 ] , indices: 88 1 20 ## 0 1 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.47282  in range [ -25 -10 ] , indices: 88 1 20 ## 1 1 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.575000000000001  in range [ -25 -10 ] , indices: 88 1 20 ## 0 2 , size: (89, 2, 6, 42, 40)
# Writing to file for latitude  -9.486170000000001  in range [ -25 -10 ] , indices: 88 1 20 ## 1 2 , size: (89, 2, 6, 42, 40)
# track vector: 36840 0.8479100000000006 0.12628979382168967 -171.52850330110522 8.471496698894782 ## 0.8479100000000006 1 36714
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.6264042222778176 26 27.4936
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:42:19.108005120
# Writing to file for latitude  -9.22208  in range [ -25 -10 ] , indices: 89 0 40 ## 0 0 , size: (90, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.8732707740343078 207 27.17205
# Writing to file for latitude  -9.29738  in range [ -25 -10 ] , indices: 89 0 20 ## 0 0 , size: (90, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9313885512248785 247 26.998600000000003
# Writing to file for latitude  -9.208590000000001  in range [ -25 -10 ] , indices: 89 0 20 ## 1 0 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.310870000000001  in range [ -25 -10 ] , indices: 89 0 20 ## 0 1 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.22208  in range [ -25 -10 ] , indices: 89 0 20 ## 1 1 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.324330000000002  in range [ -25 -10 ] , indices: 89 0 20 ## 0 2 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.23553  in range [ -25 -10 ] , indices: 89 0 20 ## 1 2 , size: (90, 2, 6, 42, 40)
# track vector: 36840 0.8479100000000006 0.12628979382168967 -171.52850330110522 8.471496698894782 ## 0.8479100000000006 1 36714
# Swell mask option: 7 1 -5 0.3 0.46733722158369806 22 25.895500000000002
# Writing to file for latitude  -9.29518  in range [ -25 -10 ] , indices: 89 1 40 ## 0 0 , size: (90, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9402105993146813 322 26.74615
# Writing to file for latitude  -9.370640000000002  in range [ -25 -10 ] , indices: 89 1 20 ## 0 0 , size: (90, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.9247849570076353 322 27.232100000000003
# Writing to file for latitude  -9.281830000000001  in range [ -25 -10 ] , indices: 89 1 20 ## 1 0 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.384  in range [ -25 -10 ] , indices: 89 1 20 ## 0 1 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.29518  in range [ -25 -10 ] , indices: 89 1 20 ## 1 1 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.39733  in range [ -25 -10 ] , indices: 89 1 20 ## 0 2 , size: (90, 2, 6, 42, 40)
# Writing to file for latitude  -9.30851  in range [ -25 -10 ] , indices: 89 1 20 ## 1 2 , size: (90, 2, 6, 42, 40)
# track vector: 36924 0.8478999999999992 0.12623456792579987 -171.53205570334666 8.467944296653343 ## 0.8478999999999992 1 36798
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 1 -5 0.3 0.5304595651588964 26 27.76265
# time units: seconds since 2000-01-01 00:00:00.0
# timec: 2023-08-28T09:42:22.212080768
# Writing to file for latitude  -9.044490000000001  in range [ -25 -10 ] , indices: 90 0 40 ## 0 0 , size: (91, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.9257160661620686 224 26.977450000000005
# Writing to file for latitude  -9.119800000000001  in range [ -25 -10 ] , indices: 90 0 20 ## 0 0 , size: (91, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.8998324462463713 259 27.136250000000004
# Writing to file for latitude  -9.031020000000002  in range [ -25 -10 ] , indices: 90 0 20 ## 1 0 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.133270000000001  in range [ -25 -10 ] , indices: 90 0 20 ## 0 1 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.044490000000001  in range [ -25 -10 ] , indices: 90 0 20 ## 1 1 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.14672  in range [ -25 -10 ] , indices: 90 0 20 ## 0 2 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.05793  in range [ -25 -10 ] , indices: 90 0 20 ## 1 2 , size: (91, 2, 6, 42, 40)
# track vector: 36924 0.8478999999999992 0.12623456792579987 -171.53205570334666 8.467944296653343 ## 0.8478999999999992 1 36798
# Swell mask option: 7 1 -5 0.3 0.4553824103712942 24 26.32465
# Writing to file for latitude  -9.117550000000001  in range [ -25 -10 ] , indices: 90 1 40 ## 0 0 , size: (91, 1, 2, 21, 20)
# /home/ardhuin/.local/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Swell mask option: 7 0 -5 0.3 0.8501038160058055 250 26.5869
# Writing to file for latitude  -9.19302  in range [ -25 -10 ] , indices: 90 1 20 ## 0 0 , size: (91, 2, 6, 42, 40)
# Swell mask option: 7 0 -5 0.3 0.8756361001787536 274 26.813100000000002
# Writing to file for latitude  -9.10421  in range [ -25 -10 ] , indices: 90 1 20 ## 1 0 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.20636  in range [ -25 -10 ] , indices: 90 1 20 ## 0 1 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.117550000000001  in range [ -25 -10 ] , indices: 90 1 20 ## 1 1 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.21969  in range [ -25 -10 ] , indices: 90 1 20 ## 0 2 , size: (91, 2, 6, 42, 40)
# Writing to file for latitude  -9.130870000000002  in range [ -25 -10 ] , indices: 90 1 20 ## 1 2 , size: (91, 2, 6, 42, 40)
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     dimensions(sizes): time(91), nind(4), nboy_40(1), nbox_40(2), nboy_20(2), nbox_20(6), nboy_10(4), nbox_10(14), nky_40(21), nkx_40(20), nky_20(42), nkx_20(40), nf(36), ntheta(24)
#     variables(dimensions): float64 time(time), float64 boxindices_40(time, nboy_40, nbox_40, nind), float32 trackangle(time), float32 Q18_40(time, nboy_40, nbox_40), float32 longitude_40(time, nboy_40, nbox_40), float32 latitude_40(time, nboy_40, nbox_40), float32 sigma0_mean_40(time, nboy_40, nbox_40), float32 sigma0_std_40(time, nboy_40, nbox_40), float32 H18_40(time, nboy_40, nbox_40), float32 L18_40(time, nboy_40, nbox_40), float32 d18_40(time, nboy_40, nbox_40), float32 quality_frac_40(time, nboy_40, nbox_40), int32 quality_flag_mask_40(time, nboy_40, nbox_40), float32 kx2_40(nky_40, nkx_40), float32 ky2_40(nky_40, nkx_40), float32 filter_OBP_40(nky_40, nkx_40), float32 filter_PTR_40(nky_40, nkx_40), float32 E_SWOT_40(time, nboy_40, nbox_40, nky_40, nkx_40), int8 mask_40(time, nboy_40, nbox_40, nky_40, nkx_40), float32 longitude_20(time, nboy_20, nbox_20), float32 latitude_20(time, nboy_20, nbox_20), float32 sigma0_mean_20(time, nboy_20, nbox_20), float32 sigma0_std_20(time, nboy_20, nbox_20), float32 H18_20(time, nboy_20, nbox_20), float32 L18_20(time, nboy_20, nbox_20), float32 d18_20(time, nboy_20, nbox_20), float32 quality_frac_20(time, nboy_20, nbox_20), int32 quality_flag_mask_20(time, nboy_20, nbox_20), float32 kx2_20(nky_20, nkx_20), float32 ky2_20(nky_20, nkx_20), float32 filter_OBP_20(nky_20, nkx_20), float32 filter_PTR_20(nky_20, nkx_20), float32 E_SWOT_20(time, nboy_20, nbox_20, nky_20, nkx_20), int8 mask_20(time, nboy_40, nbox_40, nky_20, nkx_20), float32 coh_SWOT_40(time, nboy_40, nbox_40, nky_40, nkx_40), float32 ang_SWOT_40(time, nboy_40, nbox_40, nky_40, nkx_40), float32 crosr_SWOT_40(time, nboy_40, nbox_40, nky_40, nkx_40), float32 frequency(nf), float32 df(nf), float32 direction(ntheta), float32 efth_model(time, nboy_40, nbox_40, nf, ntheta), float32 longitude_model(time, nboy_40, nbox_40), float32 latitude_model(time, nboy_40, nbox_40), float32 time_model(time, nboy_40, nbox_40), int32 index_model(time, nboy_40, nbox_40), float32 Q18_model(time, nboy_40, nbox_40), float32 H18_model(time, nboy_40, nbox_40), float32 L18_model(time, nboy_40, nbox_40), float32 d18_model(time, nboy_40, nbox_40), float32 Hs_model(time, nboy_40, nbox_40), float32 Tm02_model(time, nboy_40, nbox_40), float32 lambdac_model(time, nboy_40, nbox_40), float32 Qkk_model(time, nboy_40, nbox_40), float32 U10_model(time, nboy_40, nbox_40), float32 Udir_model(time, nboy_40, nbox_40)
#     groups:

# %%
print(SL3_nc)
SL3_nc.close()
