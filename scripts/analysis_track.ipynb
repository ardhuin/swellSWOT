# %%
import pylab as plt
import numpy as np
import swot_ssh_utils as swot
import swot_swell_utils as swell
from cartopy import crs as ccrs
from netCDF4 import Dataset
import xarray as xr
from scipy import ndimage

import sys as sys
import pickle
import glob as glob
import datetime


import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors
from matplotlib.pyplot import cm
import cmocean
import cmocean.cm as cmo

#PATH_with_functions = '/home/ardhuin/TOOLS/OPTOOLS/PYTHON/'
#sys.path.append(PATH_with_functions)
from  spectral_analysis_functions import *
from  wave_physics_functions import *
plt.rcParams.update({'font.size': 18,'savefig.facecolor':'white'})

cNorm = mcolors.Normalize(vmin=0, vmax=2)
jet = plt.get_cmap('jet')
mpl.rcParams.update({'figure.figsize':[10,6],'axes.grid' : True,'font.size': 14,'savefig.facecolor':'white'})

# %%
# Note : other tests with different spectral resolution are in directories LOOP, LOOP2, LOOP3

adjust_azc=0
if adjust_azc==1 :
   filetr='/media/ardhuin/FabLinux/WW3-SWOT/GLOBAL_REF102040/SWOT_WW3-GLOB-30M_202307_trck.nc'
   ds_ww3t = xr.open_dataset(filetr)
   modang=np.mod(90-ds_ww3t.direction,360)
   moddf=ds_ww3t.frequency2.values-ds_ww3t.frequency1.values 
   modf=ds_ww3t.frequency.values
   modnth=np.shape(modang)[0]
   moddth=(2*np.pi/modnth)

calibration=1.0
modeltag='' #'_T702'
denoise=1
figh=6.
# track for Figure 4.a
cycle='546';tracks='019';latrange=[-65,-40];Lrange=[500,1100];Lstep=100;thrange=[225,270];thstep=10;Hrange=[0,5.0];locleg='lower right';ileg=1;figh=7.;

#cycle='547';tracks='008';latrange=[-20,-8];Lrange=[500,1100];Lstep=100;thrange=[190,240];thstep=10;Hrange=[0,1.5];locleg='upper right';ileg=0;

# track for Figure 4.b
cycle='547';tracks='021';latrange=[-60,-37];Lrange=[500,800];Lstep=50;thrange=[0,30];thstep=5;Hrange=[0,0.6];locleg='lower right';ileg=0;figh=7;

# track for Figure S7a
#cycle='548';tracks='017';figh=7;figANIMA=8;latrange=[-55,-30];Lrange=[400,1000];Lstep=100;thrange=[180,270];thstep=15;Hrange=[0,3];locleg='lower right';ileg=1;latshift=3.
# track for Figure S7b
cycle='550';tracks='017';figh=7;latrange=[-32,0];Lrange=[400,1000];Lstep=100;thrange=[180,240];thstep=15;Hrange=[0,2.5];locleg='upper right';ileg=0;latshift=7.


# track with buoys 
# Fig. S2.a 
cycle='556';days='20230618';tracks='015';figh=5.;latrange=[35,59.6];Lrange=[500,800];Lstep=100;thrange=[180,240];thstep=15;Hrange=[0,0.3];locleg='lower right';ileg=1;  

#cycle='545';tracks='010';latrange=[-45,-30];Lrange=[400,800];Lstep=100;thrange=[180,240];thstep=15;Hrange=[0,7];locleg='upper right';ileg=0;
#cycle='546';tracks='010';latrange=[-45,-30];Lrange=[400,800];Lstep=100;thrange=[180,240];thstep=15;Hrange=[0,3];locleg='lower right';ileg=1;

#cycle='006';tracks='582';latrange=[40,57];Lrange=[600,1100];Lstep=100;thrange=[195,300];thstep=15;Hrange=[0,1.5];locleg='lower right';ileg=0;figh=7;latshift=0;
#cycle='001';tracks='485';latrange=[40,57];Lrange=[600,1100];Lstep=100;thrange=[195,300];thstep=15;Hrange=[0,1.5];locleg='lower right';ileg=0;figh=7;latshift=0;

folder='ANIMATIONS/'+cycle+'_'+tracks
print('looking for files:',folder+'/SWOT_swell_spectra_'+cycle+'_'+tracks+'_left_*.npz' ) 
file_lisr = sorted(glob.glob(folder+'/SWOT_swell_spectra_'+cycle+'_'+tracks+'_left_*.npz'));
#file_list = sorted(glob.glob('LOOP3/SWOT_swell*_'+tracks+'left_*.npz'));
nfiles=len(file_lisr)
#file_lisl = sorted(glob.glob('ANIMATIONS'+modeltag+'/SWOT_swell_spectra_'+cycle+'_'+tracks+'_right_*.npz'));
file_lisl = sorted(glob.glob(folder+'/SWOT_swell_spectra_'+cycle+'_'+tracks+'_right_*.npz'));
nfilel=len(file_lisl)
tracktag='cycle '+cycle+', track '+tracks;
print('We have ',nfiles,nfilel,' files.')
bigarray=np.zeros((nfiles+nfilel,50))
indf=0
obpfilter='H2'
for file_list in [file_lisr,file_lisl]:
  #for file_box in file_list:
  for file_box in file_list:
    #print('reading file ',file_box)
    data = np.load(file_box,allow_pickle=True)
    for k in data.keys():
        exec(k+' = data["'+k+'"]')
        if (indf == 0):
            print(k+' = data["'+k+'"]')

    
    dlat=np.sin(-trackangle*np.pi/180)
    #amask,bmask=swell.SWOTdefine_swell_mask_simple(E_WW3_noa_H2/HH2,coh,ang,sig0mean,dlat,kx2,ky2,mask_choice=0)
    #amask,bmask=swell.SWOTdefine_swell_mask_simple(E_WW3_noa_H2/HH2,coh,ang,sig0mean,dlat,kx2,ky2,mask_choice=-3)
    #amask,bmask=swell.SWOTdefine_swell_mask_simple(E_SWOT/HH2,coh,ang,sig0mean,dlat,kx2,ky2,mask_choice=1)
    #amask=ndimage.binary_dilation((amask > 0.5).astype(int))
    
    # Computes a calibration transfer function: Hptr to some power ... 
    #if (indf==0):
    #    HsWW3=2.
    #    Tm02WW3=4.
    print(file_box,modelfound)
    # uses values from *npz files: full spectrum 
    if modelfound > 0 :
      sigu=(HsWW3/4)*(2*np.pi/Tm02WW3)
      kc=(7310/875.0e3)/sigu/(2*np.pi)
    else :
      kc=0.3
    Hazc_old =np.exp(-(ky2/kc)**2)
    Hazc_new = Hazc_old
    if adjust_azc==1:
        # recomputes sigu (standard dev. of orbital velocity) for a filtered spectrum (cutting at 100 m wavelength) 
        modspec=ds_ww3t.efth[indww3].squeeze() 
        efth=modspec.values;
        # this was to check that we get the same numbers again ... 
        #[Ef,th1m,sth1m,Hsall,Tm0m1,Tm02all,Qf,Qkk] = wavespec_Efth_to_first3(efth,modf,moddf, modang.values,moddth,cut=10000.) 
    
        [Ef,th1m,sth1m,Hs,Tm0m1,Tm02,Qf,Qkk] = wavespec_Efth_to_first3(efth,modf,moddf, modang.values,moddth,cut=250.) 
    
        sigu3=(Hs/4)*(2*np.pi/Tm02)
        kc=(7310/875.0e3)/sigu/(2*np.pi)
        Hazc_old =np.exp(-(ky2/kc)**2)
        #print('TEST:',latc,Hs,Tm02,sigu3,1/kc) 

        kc=(7310/875.0e3)/sigu3/(2*np.pi)
        Hazc_new =np.exp(-(ky2/kc)**2)
    
    HHC=(HH2/(HH*Hazc_old))**(calibration-1)
    HH3=(HH2/Hazc_old)*HHC*Hazc_new  # filter corrected with calibration for Hptr and new cut-off for Hazc. 
    
    # NB: to be fully correct we should also redo the aliasing calculation with the updated filter ...
   
    bigarray[indf,0]=timec
    bigarray[indf,1]=lonc
    bigarray[indf,2]=latc
    bigarray[indf,3]=timeww3
    bigarray[indf,4]=1/kc
    
        
    if obpfilter=='H':
        Hsnew,Lmm1new,Lmnew,dmnew,Q18=swell.SWOTspec_to_HsLm(E_SWOT,kx2,ky2,amask,HH,trackangle)
    else:
        Hsnew,Lmm1new,Lmnew,dmnew,Q18=swell.SWOTspec_to_HsLm(E_SWOT,kx2,ky2,amask,HH3,trackangle)
    bigarray[indf,10]=Hsnew
    bigarray[indf,20]=Lmm1new
    bigarray[indf,30]=dmnew
    if (denoise==1):
       Ekth,kn1,theta1,Eta_SWOT_nonoise=swell.SWOT_denoise_isotropic(E_SWOT/HH3,kx2,ky2)
       Hsnew,Lmm1new,Lmnew,dmnew,Q18=swell.SWOTspec_to_HsLm(Eta_SWOT_nonoise,kx2,ky2,amask,(HH2*0+1),trackangle)
       bigarray[indf,12]=Hsnew
       bigarray[indf,22]=Lmm1new
       bigarray[indf,32]=dmnew
    
    
    b2mask=amask
# uses a slightly wider mask for the model to be sure to catch the full partition 
    b2mask=ndimage.binary_dilation((amask > 0.5).astype(int))
    #
    if obpfilter=='H':
        Hsnew,Lmm1new,Lmnew,dmnew,Q18=swell.SWOTspec_to_HsLm(E_WW3_obp_H,kx2,ky2,b2mask,HH,trackangle)
    else:
        Hsnew,Lmm1new,Lmnew,dmnew,Q18=swell.SWOTspec_to_HsLm(E_WW3_obp_H2,kx2,ky2,b2mask,HH2,trackangle)
    bigarray[indf,11]=Hsnew
    bigarray[indf,21]=Lmm1new
    bigarray[indf,31]=dmnew
    indf=indf+1

tshift=86400   #

new_time = timec+np.timedelta64(int(np.round(tshift*1e9)), 'ns')
times=str(new_time)[0:4]+str(new_time)[5:7]+str(new_time)[8:10]
#print('timec:',timec,'##',times,'##') 
files_SWIM = sorted(glob.glob('SWIM*'+times+'*10.pickle'))
lenSWIM=len(files_SWIM)
if (lenSWIM > 0):
    print('reading SWIM data:',files_SWIM[0])
    with open(files_SWIM[0], 'rb') as pickle_file:
       SWIM = pickle.load(pickle_file)
    
gr=[0.,205./255.,0.]
fig,axs=plt.subplots(1,4,figsize=(16,figh))
vecHs=np.linspace(1,12,23)
if nfiles*nfilel > 0  :
   axs[0].scatter(bigarray[0:nfiles,11],bigarray[0:nfiles,2],c='black',linewidth=1,label='model left');
   axs[0].scatter(bigarray[nfiles+1:-1,11],bigarray[nfiles+1:-1,2],c='blue',linewidth=1,label='model  right');
   axs[0].scatter(bigarray[nfiles+1:-1,10],bigarray[nfiles+1:-1,2],c=gr,linewidth=1,label='SWOT  right');
   axs[0].scatter(bigarray[0:nfiles,10],bigarray[0:nfiles,2],c='red',linewidth=1,label='SWOT left');
else: 
   gr=[200./255.,200./255.,200./255.]
   gS=[80./255.,255./255.,80./255.]
   axs[0].scatter(bigarray[0:-1,11],bigarray[0:-1,2],c='black',linewidth=1,label='model');
   axs[0].scatter(bigarray[0:-1,10],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT');
   if (denoise==1):
      axs[0].scatter(bigarray[0:-1,12],bigarray[0:-1,2],c='red',alpha=0.5,linewidth=1,label='denoised');
   if (lenSWIM > 0):
     axs[0].scatter(SWIM['swell_hs'],SWIM['latitude']+latshift,c=gS,alpha=1.,linewidth=1,label='SWIM 10°');

    
axs[0].set_xlabel(r'$H_{18}$ (m)', fontsize=18)
axs[0].set_ylabel('latitude (deg)', fontsize=18)
axs[0].set_title(tracktag, fontsize=18)
axs[0].set_xlim(Hrange);
#axs[0].set_xlim([0,5]);
axs[0].set_ylim(latrange)

if nfiles*nfilel > 0  :
   axs[1].scatter(bigarray[0:nfiles,21],bigarray[0:nfiles,2],c='black',linewidth=1,label='model left');
   axs[1].scatter(bigarray[nfiles+1:-1,21],bigarray[nfiles+1:-1,2],c='blue',linewidth=1,label='model  right');
   axs[1].scatter(bigarray[nfiles+1:-1,20],bigarray[nfiles+1:-1,2],c=gr,linewidth=1,label='SWOT  right');
   axs[1].scatter(bigarray[0:nfiles,20],bigarray[0:nfiles,2],c='red',linewidth=1,label='SWOT left');
else: 
   axs[1].scatter(bigarray[0:-1,21],bigarray[0:-1,2],c='black',linewidth=1,label='model');
   axs[1].scatter(bigarray[0:-1,20],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT'); 
   if (denoise==1):
     axs[1].scatter(bigarray[0:-1,22],bigarray[0:-1,2],c='red',alpha=0.5,linewidth=1,label='denoised');
   if (lenSWIM > 0):
     axs[1].scatter(SWIM['swell_wl'],SWIM['latitude']+latshift,c=gS,alpha=1.,linewidth=1,label='SWIM 10°');

axs[1].set_xlabel(r'$L_{18}$ (m)', fontsize=18)
format = '%Y-%m-%dT%H:%M:%S'
axs[1].set_title(str(timec)[0:16], fontsize=18)
axs[1].set_xlim(Lrange)
axs[1].set_xticks(np.arange(Lrange[0],Lrange[1],Lstep))
#axs[1].set_xlim([450,650])
#axs[1].set_xticks(np.arange(450,650,50))
axs[1].set_ylim(latrange)
leg = axs[ileg].legend(loc=locleg, fontsize=14)

lightcmap = cmocean.tools.lighten(cmo.ice_r, 0.5)

if nfiles*nfilel > 0  :
   axs[2].scatter(bigarray[0:nfiles,31],bigarray[0:nfiles,2],c='black',linewidth=1,label='model left');
   axs[2].scatter(bigarray[nfiles+1:-1,31],bigarray[nfiles+1:-1,2],c='blue',linewidth=1,label='model right');
   axs[2].scatter(bigarray[nfiles+1:-1,30],bigarray[nfiles+1:-1,2],c=gr,linewidth=1,label='SWOT right');
   axs[2].scatter(bigarray[0:nfiles,30],bigarray[0:nfiles,2],c='red',linewidth=1,label='SWOT left');
else: 
   axs[2].scatter(bigarray[0:-1,31],bigarray[0:-1,2],c='black',linewidth=1,label='model');
   axs[2].scatter(bigarray[0:-1,30],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT');
   if (denoise==1):
     axs[2].scatter(bigarray[0:-1,32],bigarray[0:-1,2],c='red',alpha=0.5,linewidth=1,label='denoised');
   if (lenSWIM > 0):
     axs[2].scatter(SWIM['swell_dir'],SWIM['latitude']+latshift,c=gS,alpha=1.,linewidth=1,label='SWIM 10°');

axs[2].set_xlabel(r'$\theta_{18}$ (deg. nautical,from)', fontsize=18)
axs[2].set_xlim(thrange)
axs[2].set_xticks(np.arange(thrange[0],thrange[1],thstep))
axs[2].set_ylim(latrange)
#axs[2].set_title(tracktag)

if nfiles*nfilel > 0  :
   axs[3].scatter(bigarray[0:nfiles,4],bigarray[0:nfiles,2],c='black',linewidth=1,label='model left');
   axs[3].scatter(bigarray[nfiles+1:-1,4],bigarray[nfiles+1:-1,2],c='blue',linewidth=1,label='model right');
else: 
   axs[3].scatter(bigarray[0:-1,4],bigarray[0:-1,2],c='black',linewidth=1,label='model');

axs[3].set_xlabel(r'az cut-off $\lambda_c$ (m)', fontsize=18)    
axs[3].set_ylim(latrange)
if obpfilter=='H':
    fig.savefig('fulltrack_'+str(cycle)+'_'+str(tracks)+'_H.pdf')
else:
    fig.savefig('fulltrack_'+str(cycle)+'_'+str(tracks)+'_H2azc_cal'+modeltag+f'{abs(calibration):03.1f}'+'.pdf')
# Out:
# looking for files: ANIMATIONS/556_015/SWOT_swell_spectra_556_015_left_*.npz
# We have  0 158  files.
# fileSWOT = data["fileSWOT"]
# cycle = data["cycle"]
# tracks = data["tracks"]
# side = data["side"]
# boxindices = data["boxindices"]
# lonc = data["lonc"]
# latc = data["latc"]
# timec = data["timec"]
# trackangle = data["trackangle"]
# kx2 = data["kx2"]
# ky2 = data["ky2"]
# E_SWOT = data["E_SWOT"]
# sig0_spec = data["sig0_spec"]
# coh = data["coh"]
# ang = data["ang"]
# amask = data["amask"]
# sig0mean = data["sig0mean"]
# sig0std = data["sig0std"]
# HH = data["HH"]
# HH2 = data["HH2"]
# Hs_SWOT_filtered_all = data["Hs_SWOT_filtered_all"]
# Hs_SWOT_filtered_mask = data["Hs_SWOT_filtered_mask"]
# Hs_SWOT_mask = data["Hs_SWOT_mask"]
# Lm_SWOT_filtered_mask = data["Lm_SWOT_filtered_mask"]
# dm_SWOT_filtered_mask = data["dm_SWOT_filtered_mask"]
# modelfound = data["modelfound"]
# timeww3 = data["timeww3"]
# lonww3 = data["lonww3"]
# latww3 = data["latww3"]
# indww3 = data["indww3"]
# distww3 = data["distww3"]
# E_WW3_obp_H = data["E_WW3_obp_H"]
# E_WW3_obp_H2 = data["E_WW3_obp_H2"]
# E_WW3_noa_H2 = data["E_WW3_noa_H2"]
# Hs_WW3_all = data["Hs_WW3_all"]
# Hs_WW3_cut = data["Hs_WW3_cut"]
# Hs_WW3_filtered_mask = data["Hs_WW3_filtered_mask"]
# HsWW3 = data["HsWW3"]
# Tm0m1WW3 = data["Tm0m1WW3"]
# Tm02WW3 = data["Tm02WW3"]
# U10WW3 = data["U10WW3"]
# UdirWW3 = data["UdirWW3"]
# QkkWW3 = data["QkkWW3"]
# Lm_WW3 = data["Lm_WW3"]
# dm_WW3 = data["dm_WW3"]
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_34.99N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_35.16N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_35.33N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_35.50N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_35.66N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_35.83N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.00N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.17N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.34N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.50N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.67N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_36.84N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.01N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.17N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.34N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.51N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.68N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_37.85N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.01N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.18N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.68N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_38.85N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.18N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_39.85N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.36N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_40.86N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.36N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_41.86N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.36N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.53N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_42.86N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.36N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_43.86N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.36N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.69N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_44.85N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.02N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.52N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.68N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_45.85N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.01N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.18N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.51N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.68N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_46.84N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.01N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.17N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.34N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.50N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.67N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_47.83N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.00N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.16N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.33N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.49N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.66N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.82N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_48.99N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.15N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.32N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.48N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.65N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.81N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_49.98N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.14N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.30N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.47N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.63N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.80N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_50.96N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.12N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.29N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.45N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.61N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.78N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_51.94N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.10N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.27N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.43N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.59N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.76N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_52.92N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.08N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.25N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.41N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.57N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.73N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_53.90N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.06N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.22N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.38N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.54N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.71N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_54.87N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.03N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.51N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.68N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_55.84N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.00N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.16N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.32N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.48N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.64N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.80N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_56.96N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.12N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.28N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.44N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.60N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.76N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_57.92N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.08N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.24N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.40N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.56N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.72N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_58.88N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.03N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.19N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.35N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.51N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.67N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.82N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_59.98N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_60.14N.npz 1
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_60.29N.npz 0
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_60.45N.npz 0
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_60.61N.npz 0
# ANIMATIONS/556_015/SWOT_swell_spectra_556_015_right_60.77N.npz 0
# /tmp/ipykernel_668555/1087425327.py:165: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axs[0].scatter(bigarray[0:-1,10],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT');
# /tmp/ipykernel_668555/1087425327.py:186: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axs[1].scatter(bigarray[0:-1,20],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT');
# /tmp/ipykernel_668555/1087425327.py:211: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axs[2].scatter(bigarray[0:-1,30],bigarray[0:-1,2],c=gr,alpha=0.5,linewidth=1,label='SWOT');

# %%
if (lenSWIM > 0):
    with open(files_SWIM[0], 'rb') as pickle_file:
        SWIM = pickle.load(pickle_file)
    print('##',SWIM['longitude'])
#SWIMlon = [item['longitude'] for item in SWIM.items()]
#WIMlon = [value['longitude'] for key, value in SWIM.items()]
#print(SWIM.items())

# %%
# Checks a few things on masks

# selects one file at a given latitude: 
file_box='ANIMATION/SWOT_swell_spectra_556_015_right_55.00N.npz'
#file_box='ANIMATION/SWOT_swell_spectra_550_017_left_30.00S.npz'
#lonlat=f'{abs(latc):05.2f}'+hemiNS[int(np.sign(latc))]
#filetag='SWOT_'+cycle+'_'+tracks+'_'+side+'_'+days+'_'+lonlat
    
data = np.load(file_box,allow_pickle=True)
for k in data.keys():
    exec(k+' = data["'+k+'"]')

dlat=np.sin(-trackangle*np.pi/180)

amask2,bmask2=swell.SWOTdefine_swell_mask_simple(E_WW3_noa_H2/HH2,coh,ang,sig0mean,dlat,kx2,ky2,mask_choice=-3)
#amask2,bmask2=SWOTdefine_swell_mask_simple(E_SWOT/HH2,coh,ang,sig0mean,dlat,kx2,ky2,mask_choice=1)

vertices=swell.SWOTspec_mask_polygon(E_SWOT,amask) 
vertices2=swell.SWOTspec_mask_polygon(E_SWOT,amask2) 

fig, ax = plt.subplots(nrows=1, ncols=4,figsize=(15,7))
plt.subplots_adjust(left=0.05,bottom=0.07, top=0.92,wspace=0.12,right=0.99)
im=ax[0].pcolormesh(kx2*1000,ky2*1000,10*np.log10(E_SWOT/HH2),cmap='viridis',rasterized=True,vmin=10, vmax=60)
_=plt.colorbar(im,ax=ax[0],label='', location='bottom',shrink=0.8)
_=ax[0].set_title('spectrum (dB)')

dkx=kx2[0,1]-kx2[0,0]
dky=ky2[1,0]-ky2[0,0]
for ind in range(len(vertices) // 4):
           xy2=np.asfarray(vertices[ind*4:(ind+1)*4])
           ax[0].plot(kx2[0,0]*1000+1000*dkx*xy2[0:2],ky2[0,0]*1000+1000*dky*xy2[2:4], color='w',lw=3)

for ind in range(len(vertices2) // 4):
           xy2=np.asfarray(vertices2[ind*4:(ind+1)*4])
           ax[0].plot(kx2[0,0]*1000+1000*dkx*xy2[0:2],ky2[0,0]*1000+1000*dky*xy2[2:4], color='y',lw=3)


Ekth,kn1,theta1,Eta_SWOT_nonoise=swell.SWOT_denoise_isotropic(E_SWOT/HH2,kx2,ky2)
            

im=ax[1].pcolormesh(kx2*1000,ky2*1000,10*np.log10(Eta_SWOT_nonoise),cmap='viridis',rasterized=True,vmin=10, vmax=60)
_=plt.colorbar(im,ax=ax[1],label='', location='bottom',shrink=0.8)
_=ax[1].set_title('spectrum denoised (dB)')

im=ax[2].pcolormesh(kx2*1000,ky2*1000,10*np.log10(E_WW3_obp_H2/HH2),cmap='viridis',rasterized=True,vmin=10, vmax=60)
_=plt.colorbar(im,ax=ax[2],label='', location='bottom',shrink=0.8)
_=ax[2].set_title('model spectrum')

im=ax[3].pcolormesh(kx2*1000,ky2*1000,10*np.log10(E_WW3_noa_H2/HH2),cmap='viridis',rasterized=True,vmin=10, vmax=60)
_=plt.colorbar(im,ax=ax[3],label='', location='bottom',shrink=0.8)
_=ax[3].set_title('model spectrum, no alias')


plt.show()

# %%
# Checks a few things on filters
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(10.8,8.5))
plt.subplots_adjust(left=0.05,bottom=0.07, top=0.92,wspace=0.12,right=0.99)
im=ax[0].pcolormesh(kx2*1000,ky2*1000,10*np.log10(HH),cmap='viridis',rasterized=True,vmin=-30, vmax=0)
_=plt.colorbar(im,ax=ax[0],label='', location='bottom',shrink=0.8)
_=ax[0].set_title('H filter (dB)')

Hazc = np.exp(-(ky2/kc)**2)
print('kc:',kc,1/kc)    
Hptr=np.sqrt(HH3/(HH*Hazc))
im=ax[1].pcolormesh(kx2*1000,ky2*1000,10*np.log10(Hptr*Hazc),cmap='viridis',rasterized=True,vmin=-10, vmax=0)
_=plt.colorbar(im,ax=ax[1],label='', location='bottom',shrink=0.8)
_=ax[1].set_title('Hptr x Hazc filter (dB)')
plt.show()
# Out:
# kc: 0.0057466581440897965 174.01417918489884

# %%
# Checks a few things on filters
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(10.8,8.5))
plt.subplots_adjust(left=0.05,bottom=0.07, top=0.92,wspace=0.12,right=0.99)
im=ax[0].pcolormesh(kx2*1000,ky2*1000,10*np.log10(HH),cmap='viridis',rasterized=True,vmin=-40, vmax=0)
_=plt.colorbar(im,ax=ax[0],label='', location='bottom',shrink=0.8)
_=ax[0].set_title('H filter (dB)')
          
    
im=ax[1].pcolormesh(kx2*1000,ky2*1000,10*np.log10(HH2/HH),cmap='viridis',rasterized=True,vmin=-10, vmax=0)
_=plt.colorbar(im,ax=ax[1],label='', location='bottom',shrink=0.8)
_=ax[1].set_title('Hptr filter (dB)')
plt.show()
